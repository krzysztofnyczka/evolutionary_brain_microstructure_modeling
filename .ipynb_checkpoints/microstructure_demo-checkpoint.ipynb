# %% [markdown]
# # Evolutionary Algorithms in Brain Microstructure Modeling

# %% [markdown]
# ## Magnetic Resonance Imaging (MRI)
#
# MRI allows to acquire images of living tissue, e.g. human brain. Typically, every image voxel represents a cubic volume of dimensions from 1x1x1 [mm] to 2x2x2 [mm], depending on MRI scanner parameters. Such resolution allows for instance to delineate grey and white matter tissue, as illustrated below.
# <br /><br />
#
# <div align="center">
#    <img src="hcp_sample_t1.png" width="80%" />
#    sample T1-weighted image,
#    <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# <strong>Grey matter</strong> comprises of densely packed neuronal bodies, whereas <strong>white matter</strong> is formed of axons and dendrites aligned in fiber bundles. The bundles play a role of neuronal connections between distant grey matter areas, resembling a network of "highways" inside the brain.
# <br /><br />
#
# <div align="center">
#    <img src="white_matter_tracts.png" width="80%" />
#    sample white matter tracts,
#    <em>source: https://radiologykey.com/white-matter-tracts/</em>
# </div>
#
# <br />

# %% [markdown]
# ## Diffusion Weighted Imaging (DWI)
#
# DWI is an imaging technique that captures mean displacement of water molecules in specified 3D directions, e.g. left-right, front-rear, top-bottom:
# <br /><br />
#
# <div align="center">
#     <img src="hcp_sample_dwi.png" width="80%" />
#     sample DWI-weighted images,
#     <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# Areas of <strong>high diffusivity</strong> are represented with darkest shades on diffusion weighted images. In the example above, the diffusivity in X direction (i.e. left-right) dominates the other two directions inside the highlighed region.
# <br /><br />
#
# We know (from physics and neuroanatomy) that water inside white matter "prefers" to diffuse along fibers rather than perpendicularly. With this in mind, DWI offers us an opportunity to capture anatomical features hidden below nominal imaging resolution. In particular, post processing of diffusion weighted images gives us spacial orientations of fibers inside each voxel containing white matter.
# <br /><br />
#
# <div align="center">
#     <img src="ball_and_stick_fitted.png" width="60%" />
#     orientations of fiber bundles in a sample region of white matter,
#     <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# Further postprocessing allows to obtain <strong>tractogram</strong> which is a color-coded map of neuronal connections inside the brain. Currently, tractograms are used both in research (e.g. neuroscience) and clinical practice (e.g. pre-surgical planning).
# <br /><br />
#
# <div align="center">
#     <img src="tractogram.jpg" width="80%" />
#     sample tractogram,
#     <em>source: http://mcgovern.mit.edu/news/images/brain-scan-cover-image-summer-2013/</em>
# </div>
#
# <br />

# %% [markdown]
# ## Microstructure modeling
#
# In practice, diffusion signal is acquired from many directions and with various imaging settings. Protocols used by clinicians comprise of at least 32 images, whereas data sets processed by researchers contain even hundreds of diffusion weighted images per subject. Generally, the more images we have, the more exactly we can estimate microstructure features inside voxels.
# <br /><br />
#
# <div align="center">
#     <img src="dwi_imaging_directions.png" width="40%" />
#     sample map of imaging directions,
#     <em>source: http://www.emmanuelcaruyer.com/q-space-sampling.php</em>
# </div>
# <br />
#
# In order to process diffusion weighted images, we need a mathematical model that would fit the measured signal. One of the simplest models of this type is called <strong>Ball and Stick</strong>. The <em>ball</em> part of this model represents diffusion of extra-cellular water (that is not interesting for us now), whereas the <em>stick</em> part represents intra-cellular diffusion of water trapped inside axons.
# <br /><br />
#
# <div align="center">
#     <img src="ball_and_stick_illustration.png" width="80%" />
#     sample ball and stick configurations inside voxels
# </div>
# <br />

# %% [markdown]
# ### Ball and Stick - formal definition
#
# Let $M$ > 0 be the number of diffusion weighted images. For all $k = 1, ..., M$, the signal is modelled as
# <br /><br />
#
# <div align="center">
# $S_k = S_0 \left[ f_{ball} \cdot \exp \left(-b_k \lambda_{iso} (\mathbf{g}_k^T \mathbf{v})^2 \right) + f_{stick} \cdot \exp(-b_k \lambda_{\parallel}) \right]$,
# </div>
#
# where:
#
# - $f_{ball}, f_{stick} \in (0, 1)$ are weighing parameters of ball and stick fractions respectively,
# - $\lambda_{iso} \in \mathbb{R}$ is an isotropic diffusivity (inside the ball),
# - $\lambda_{parallel} \in \mathbb{R}$ is a parallel diffusivity (inside the stick),
# - $v = [\sin\mu_1 \cos\mu_2, \sin\mu_1 \sin\mu_2, \cos\mu_1]^T$ is a stick direction with $\mu = (\mu_1, \mu_2) \in [0, \pi] \times [0, 2\pi)$.
# - $S_0$ is the signal acquired without diffusion sensitizing gradient (given),
# - $\mathbf{g_k} \in \mathbb{R}_+^3$ and $b_k \in \mathbb{R}_+$ are the acquisition parameters (given).

# %% [markdown]
# ## Simple example
#
# The source code of this example requires <strong>dmipy</strong> module https://github.com/AthenaEPI/dmipy with its dependencies:
# - numpy >= 1.13
# - scipy
# - dipy
# - nibabel
# - cvxpy
# - fury

# %%
import nibabel as nib
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
# %matplotlib inline

import dmipy.data.saved_acquisition_schemes as saved_acquisition_schemes

from dmipy.signal_models import cylinder_models, gaussian_models
from dmipy.core.modeling_framework import MultiCompartmentModel
from dmipy.core.fitted_modeling_framework import FittedMultiCompartmentModel

from dipy.viz import window, actor

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# First, we load a sample slice of DWI data from the Human Connectome Project repository: https://www.humanconnectome.org/

# %%
data_hcp = nib.load('wu_minn_hcp_coronal_slice.nii.gz').get_data()
scheme_hcp = saved_acquisition_schemes.wu_minn_hcp_acquisition_scheme()

# %% [markdown]
# We define a rectangular Region Of Interest (ROI):

# %%
roi = {'x': 70, 'y': 70, 'width': 20, 'height': 20}
data_hcp_roi = data_hcp[
    roi['x'] : roi['x'] + roi['width'], :, roi['y'] : roi['y'] + roi['height']
]

fig, ax = plt.subplots(figsize=[10, 10])
ax.imshow(data_hcp[:, 0, :, 0].T, origin='lower', cmap='gray', interpolation='nearest')

rect = patches.Rectangle(
    (roi['x'], roi['y']), roi['width'], roi['height'], 
    linewidth = 3, edgecolor = 'r', facecolor = 'none'
)
ax.add_patch(rect)
ax.set_axis_off()
ax.set_title('Coronal slice with ROI');

# %% [markdown]
# Next, we create an instance of the Ball and Stick diffusion model.

# %%
ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])
# Out:
# We highly recommend installing numba for faster function execution and model fitting.
# We highly recommend installing pathos to take advantage of multicore processing.

# %% [markdown]
# Our model requires fitting the following five parameters for every image voxel:
# - G1Ball_1_lambda_iso – extra-cellular diffusivity coefficient (real value * $10^{-9}$),
# - C1Stick_1_mu – direction of a stick (2-dimensional real vector of sphere coordinates),
# - C1Stick_1_lambda_par – intra-cellular diffusivity coefficient (real value * $10^{-9}$),
# - partial_volume_0 – weight of the intra-cellular diffusion fraction (real value),
# - partial_volume_1 – weight of the extra-cellular diffusion fraction (real value).
#
# The ranges of parameters are given below:

# %%
bas_model.parameter_ranges
# Out:
# OrderedDict([('C1Stick_1_mu',
#               ([0, 3.141592653589793],
#                [-3.141592653589793, 3.141592653589793])),
#              ('C1Stick_1_lambda_par', (0.1, 3)),
#              ('G1Ball_1_lambda_iso', (0.1, 3)),
#              ('partial_volume_0', (0.01, 0.99)),
#              ('partial_volume_1', (0.01, 0.99))])

# %% [markdown]
# ### Dummy solution
#
# Let's try setting random parameters to our Ball and Stick model.

# %%
def set_parameters(our_voxel_bas_model, scheme_hcp, voxel_signal):
    params = []

    # estimate S0
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    # G1Ball_1_lambda_iso
    param_range = our_voxel_bas_model.parameter_ranges['G1Ball_1_lambda_iso']
    lambda_iso = np.random.uniform(param_range[0], param_range[1]) * 1e-09

    # C1Stick_1_mu
    param_ranges = our_voxel_bas_model.parameter_ranges['C1Stick_1_mu']
    mu_1 = np.random.uniform(param_ranges[0][0], param_ranges[0][1])
    mu_2 = np.random.uniform(param_ranges[1][0], param_ranges[1][1])
    
    # C1Stick_1_lambda_par
    param_range = our_voxel_bas_model.parameter_ranges['C1Stick_1_lambda_par']
    lambda_parallel = np.random.uniform(param_range[0], param_range[1]) * 1e-09
    
    # partial_volume_0
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_0']
    f_stick = np.random.uniform(param_range[0], param_range[1])
    
    # partial_volume_1
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_1']
    f_ball = np.random.uniform(param_range[0], param_range[1])
            
    return FittedMultiCompartmentModel(
        our_voxel_bas_model, np.array(S0), np.array([True]), 
        np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    our_bas_model[x] = {}
    for y in range(roi['height']):
        
        voxel_signal = data_hcp_roi[x, 0, y, :]
        our_bas_model[x][y] = set_parameters(bas_model, scheme_hcp, voxel_signal)
        
        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)
          
print("Fitting accuracy:")        
print("MSE +/- STD = %f +/- %f" % (np.mean(voxel_mse), np.std(voxel_mse)))
# Out:
# Fitting accuracy:
# MSE +/- STD = 0.111069 +/- 0.121987

# %% [markdown]
# The mean squared errors are relatively high and dispersed. The orientations of fiber bundles (red lines) and volumes of intra-cellular diffusion (grayscale shades) look random on a visualization below.

# %%
def visualize_result(bas_models_fit):

    affine = np.eye(4)
    affine[0,3] = -10
    affine[1,3] = -10

    volume = np.zeros([roi['width'], roi['height'], 1])
    peak_dirs = np.zeros([roi['width'], roi['height'], 1, 1, 3])

    for x in range(roi['width']):
        for y in range(roi['height']):
            volume[x, y, 0] = bas_models_fit[x][y].fitted_parameters['partial_volume_0']
            peak_cart = np.squeeze(bas_models_fit[x][y].peaks_cartesian())
            peak_dirs[x, y, 0] = [peak_cart[0], peak_cart[2], -peak_cart[1]]

    ren = window.ren()
    ren.add(actor.slicer(volume, interpolation='nearest', affine=affine, opacity=0.7))
    ren.add(actor.peak_slicer(peak_dirs, None, affine=affine, linewidth=5, colors=None))   

    window.record(ren, size=[700, 700], out_path='dipy.png')
    
    img = mpimg.imread('dipy.png')
    plt.figure(figsize=[10, 10])
    plt.imshow(img) #[100:-97, 100:-85])
    plt.axis('off');
    
print("our randomized model:")
visualize_result(our_bas_model)
# Out:
# our randomized model:

# %% [markdown]
# ### State-of-the-art solution
#
# For comparison, let's try now a state-of-the-art solution.

# %%
reference_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    reference_bas_model[x] = {}
    for y in range(roi['height']):
        
        voxel_signal = data_hcp_roi[x, 0, y, :]
        reference_bas_model[x][y] = bas_model.fit(scheme_hcp, voxel_signal)
        
        voxel_mse[x][y] = reference_bas_model[x][y].mean_squared_error(voxel_signal)
        
print("Fitting accuracy:")        
print("MSE +/- STD = %f +/- %f" % (np.mean(voxel_mse), np.std(voxel_mse)))
# Out:
# Setup brute2fine optimizer in 0.21743059158325195 seconds
# Fitting of 1 voxels complete in 0.04587411880493164 seconds.
# Average of 0.04587411880493164 seconds per voxel.
# Setup brute2fine optimizer in 0.20741844177246094 seconds
# Fitting of 1 voxels complete in 0.031914472579956055 seconds.
# Average of 0.031914472579956055 seconds per voxel.
# Setup brute2fine optimizer in 0.204451322555542 seconds
# Fitting of 1 voxels complete in 0.03291177749633789 seconds.
# Average of 0.03291177749633789 seconds per voxel.
# Setup brute2fine optimizer in 0.20545029640197754 seconds
# Fitting of 1 voxels complete in 0.026927709579467773 seconds.
# Average of 0.026927709579467773 seconds per voxel.
# Setup brute2fine optimizer in 0.20496320724487305 seconds
# Fitting of 1 voxels complete in 0.026928186416625977 seconds.
# Average of 0.026928186416625977 seconds per voxel.
# Setup brute2fine optimizer in 0.2358860969543457 seconds
# Fitting of 1 voxels complete in 0.03788900375366211 seconds.
# Average of 0.03788900375366211 seconds per voxel.
# Setup brute2fine optimizer in 0.23710131645202637 seconds
# Fitting of 1 voxels complete in 0.028922080993652344 seconds.
# Average of 0.028922080993652344 seconds per voxel.
# Setup brute2fine optimizer in 0.24088001251220703 seconds
# Fitting of 1 voxels complete in 0.02692890167236328 seconds.
# Average of 0.02692890167236328 seconds per voxel.
# Setup brute2fine optimizer in 0.2378082275390625 seconds
# Fitting of 1 voxels complete in 0.032886505126953125 seconds.
# Average of 0.032886505126953125 seconds per voxel.
# Setup brute2fine optimizer in 0.23905348777770996 seconds
# Fitting of 1 voxels complete in 0.028921842575073242 seconds.
# Average of 0.028921842575073242 seconds per voxel.
# Setup brute2fine optimizer in 0.23717141151428223 seconds
# Fitting of 1 voxels complete in 0.026964187622070312 seconds.
# Average of 0.026964187622070312 seconds per voxel.
# Setup brute2fine optimizer in 0.20844197273254395 seconds
# Fitting of 1 voxels complete in 0.027962446212768555 seconds.
# Average of 0.027962446212768555 seconds per voxel.
# Setup brute2fine optimizer in 0.20345544815063477 seconds
# Fitting of 1 voxels complete in 0.027952909469604492 seconds.
# Average of 0.027952909469604492 seconds per voxel.
# Setup brute2fine optimizer in 0.23038387298583984 seconds
# Fitting of 1 voxels complete in 0.0299532413482666 seconds.
# Average of 0.0299532413482666 seconds per voxel.
# Setup brute2fine optimizer in 0.21140646934509277 seconds
# Fitting of 1 voxels complete in 0.022937774658203125 seconds.
# Average of 0.022937774658203125 seconds per voxel.
# Setup brute2fine optimizer in 0.20844268798828125 seconds
# Fitting of 1 voxels complete in 0.025969982147216797 seconds.
# Average of 0.025969982147216797 seconds per voxel.
# Setup brute2fine optimizer in 0.20345520973205566 seconds
# Fitting of 1 voxels complete in 0.028957128524780273 seconds.
# Average of 0.028957128524780273 seconds per voxel.
# Setup brute2fine optimizer in 0.20748209953308105 seconds
# Fitting of 1 voxels complete in 0.022921085357666016 seconds.
# Average of 0.022921085357666016 seconds per voxel.
# Setup brute2fine optimizer in 0.20542120933532715 seconds
# Fitting of 1 voxels complete in 0.02995014190673828 seconds.
# Average of 0.02995014190673828 seconds per voxel.
# Setup brute2fine optimizer in 0.21143388748168945 seconds
# Fitting of 1 voxels complete in 0.03793907165527344 seconds.
# Average of 0.03793907165527344 seconds per voxel.
# Setup brute2fine optimizer in 0.20844197273254395 seconds
# Fitting of 1 voxels complete in 0.03493452072143555 seconds.
# Average of 0.03493452072143555 seconds per voxel.
# Setup brute2fine optimizer in 0.2124037742614746 seconds
# Fitting of 1 voxels complete in 0.031954050064086914 seconds.
# Average of 0.031954050064086914 seconds per voxel.
# Setup brute2fine optimizer in 0.20943903923034668 seconds
# Fitting of 1 voxels complete in 0.025931119918823242 seconds.
# Average of 0.025931119918823242 seconds per voxel.
# Setup brute2fine optimizer in 0.20653367042541504 seconds
# Fitting of 1 voxels complete in 0.03692960739135742 seconds.
# Average of 0.03692960739135742 seconds per voxel.
# Setup brute2fine optimizer in 0.20943975448608398 seconds
# Fitting of 1 voxels complete in 0.026966094970703125 seconds.
# Average of 0.026966094970703125 seconds per voxel.
# Setup brute2fine optimizer in 0.2071988582611084 seconds
# Fitting of 1 voxels complete in 0.022975921630859375 seconds.
# Average of 0.022975921630859375 seconds per voxel.
# Setup brute2fine optimizer in 0.20998764038085938 seconds
# Fitting of 1 voxels complete in 0.02895522117614746 seconds.
# Average of 0.02895522117614746 seconds per voxel.
# Setup brute2fine optimizer in 0.21260833740234375 seconds
# Fitting of 1 voxels complete in 0.01400613784790039 seconds.
# Average of 0.01400613784790039 seconds per voxel.
# Setup brute2fine optimizer in 0.20284700393676758 seconds
# Fitting of 1 voxels complete in 0.01894855499267578 seconds.
# Average of 0.01894855499267578 seconds per voxel.
# Setup brute2fine optimizer in 0.2082352638244629 seconds
# Fitting of 1 voxels complete in 0.019946575164794922 seconds.
# Average of 0.016155242919921875 seconds per voxel.
# Setup brute2fine optimizer in 0.22538518905639648 seconds
# Fitting of 1 voxels complete in 0.030907630920410156 seconds.
# Average of 0.030907630920410156 seconds per voxel.
# Setup brute2fine optimizer in 0.21794986724853516 seconds
# Fitting of 1 voxels complete in 0.025859832763671875 seconds.
# Average of 0.025859832763671875 seconds per voxel.
# Setup brute2fine optimizer in 0.21040797233581543 seconds
# Fitting of 1 voxels complete in 0.02593088150024414 seconds.
# Average of 0.02593088150024414 seconds per voxel.
# Setup brute2fine optimizer in 0.2124314308166504 seconds
# Fitting of 1 voxels complete in 0.023935317993164062 seconds.
# Average of 0.023935317993164062 seconds per voxel.
# Setup brute2fine optimizer in 0.2086009979248047 seconds
# Fitting of 1 voxels complete in 0.023946046829223633 seconds.
# Average of 0.023946046829223633 seconds per voxel.
# Setup brute2fine optimizer in 0.20591521263122559 seconds
# Fitting of 1 voxels complete in 0.03195786476135254 seconds.
# Average of 0.03195786476135254 seconds per voxel.
# Setup brute2fine optimizer in 0.20345568656921387 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20345234870910645 seconds
# Fitting of 1 voxels complete in 0.03291153907775879 seconds.
# Average of 0.03291153907775879 seconds per voxel.
# Setup brute2fine optimizer in 0.20345520973205566 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20245838165283203 seconds
# Fitting of 1 voxels complete in 0.02094411849975586 seconds.
# Average of 0.02094411849975586 seconds per voxel.
# Setup brute2fine optimizer in 0.20458126068115234 seconds
# Fitting of 1 voxels complete in 0.03541254997253418 seconds.
# Average of 0.03541254997253418 seconds per voxel.
# Setup brute2fine optimizer in 0.20560169219970703 seconds
# Fitting of 1 voxels complete in 0.024442195892333984 seconds.
# Average of 0.024442195892333984 seconds per voxel.
# Setup brute2fine optimizer in 0.20752739906311035 seconds
# Fitting of 1 voxels complete in 0.031914472579956055 seconds.
# Average of 0.031914472579956055 seconds per voxel.
# Setup brute2fine optimizer in 0.20345640182495117 seconds
# Fitting of 1 voxels complete in 0.023935556411743164 seconds.
# Average of 0.023935556411743164 seconds per voxel.
# Setup brute2fine optimizer in 0.20135116577148438 seconds
# Fitting of 1 voxels complete in 0.030007362365722656 seconds.
# Average of 0.030007362365722656 seconds per voxel.
# Setup brute2fine optimizer in 0.2184300422668457 seconds
# Fitting of 1 voxels complete in 0.020903825759887695 seconds.
# Average of 0.020903825759887695 seconds per voxel.
# Setup brute2fine optimizer in 0.20218586921691895 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.2009744644165039 seconds
# Fitting of 1 voxels complete in 0.026928186416625977 seconds.
# Average of 0.026928186416625977 seconds per voxel.
# Setup brute2fine optimizer in 0.21357417106628418 seconds
# Fitting of 1 voxels complete in 0.013962745666503906 seconds.
# Average of 0.013962745666503906 seconds per voxel.
# Setup brute2fine optimizer in 0.20147275924682617 seconds
# Fitting of 1 voxels complete in 0.01396322250366211 seconds.
# Average of 0.01396322250366211 seconds per voxel.
# Setup brute2fine optimizer in 0.20196175575256348 seconds
# Fitting of 1 voxels complete in 0.01795220375061035 seconds.
# Average of 0.01795220375061035 seconds per voxel.
# Setup brute2fine optimizer in 0.2074446678161621 seconds
# Fitting of 1 voxels complete in 0.027934551239013672 seconds.
# Average of 0.027934551239013672 seconds per voxel.
# Setup brute2fine optimizer in 0.2094259262084961 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.21023344993591309 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.20444512367248535 seconds
# Fitting of 1 voxels complete in 0.026927709579467773 seconds.
# Average of 0.026927709579467773 seconds per voxel.
# Setup brute2fine optimizer in 0.21193885803222656 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.20311880111694336 seconds
# Fitting of 1 voxels complete in 0.02216958999633789 seconds.
# Average of 0.02216958999633789 seconds per voxel.
# Setup brute2fine optimizer in 0.20415496826171875 seconds
# Fitting of 1 voxels complete in 0.0249330997467041 seconds.
# Average of 0.0249330997467041 seconds per voxel.
# Setup brute2fine optimizer in 0.20259404182434082 seconds
# Fitting of 1 voxels complete in 0.02544379234313965 seconds.
# Average of 0.02544379234313965 seconds per voxel.
# Setup brute2fine optimizer in 0.20553994178771973 seconds
# Fitting of 1 voxels complete in 0.04588198661804199 seconds.
# Average of 0.04588198661804199 seconds per voxel.
# Setup brute2fine optimizer in 0.20797348022460938 seconds
# Fitting of 1 voxels complete in 0.016954660415649414 seconds.
# Average of 0.016954660415649414 seconds per voxel.
# Setup brute2fine optimizer in 0.20389437675476074 seconds
# Fitting of 1 voxels complete in 0.035902976989746094 seconds.
# Average of 0.035902976989746094 seconds per voxel.
# Setup brute2fine optimizer in 0.2034752368927002 seconds
# Fitting of 1 voxels complete in 0.02792525291442871 seconds.
# Average of 0.02792525291442871 seconds per voxel.
# Setup brute2fine optimizer in 0.21442627906799316 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.20444536209106445 seconds
# Fitting of 1 voxels complete in 0.030944347381591797 seconds.
# Average of 0.030944347381591797 seconds per voxel.
# Setup brute2fine optimizer in 0.21037912368774414 seconds
# Fitting of 1 voxels complete in 0.02593064308166504 seconds.
# Average of 0.02593064308166504 seconds per voxel.
# Setup brute2fine optimizer in 0.20324087142944336 seconds
# Fitting of 1 voxels complete in 0.019946813583374023 seconds.
# Average of 0.019946813583374023 seconds per voxel.
# Setup brute2fine optimizer in 0.20545029640197754 seconds
# Fitting of 1 voxels complete in 0.025931119918823242 seconds.
# Average of 0.025931119918823242 seconds per voxel.
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20076704025268555 seconds
# Fitting of 1 voxels complete in 0.033417701721191406 seconds.
# Average of 0.033417701721191406 seconds per voxel.
# Setup brute2fine optimizer in 0.2074451446533203 seconds
# Fitting of 1 voxels complete in 0.013962507247924805 seconds.
# Average of 0.013962507247924805 seconds per voxel.
# Setup brute2fine optimizer in 0.2162010669708252 seconds
# Fitting of 1 voxels complete in 0.015001535415649414 seconds.
# Average of 0.015001535415649414 seconds per voxel.
# Setup brute2fine optimizer in 0.20440959930419922 seconds
# Fitting of 1 voxels complete in 0.013962507247924805 seconds.
# Average of 0.013962507247924805 seconds per voxel.
# Setup brute2fine optimizer in 0.23537063598632812 seconds
# Fitting of 1 voxels complete in 0.026928186416625977 seconds.
# Average of 0.026928186416625977 seconds per voxel.
# Setup brute2fine optimizer in 0.23097586631774902 seconds
# Fitting of 1 voxels complete in 0.03191494941711426 seconds.
# Average of 0.03191494941711426 seconds per voxel.
# Setup brute2fine optimizer in 0.2273721694946289 seconds
# Fitting of 1 voxels complete in 0.02692890167236328 seconds.
# Average of 0.02692890167236328 seconds per voxel.
# Setup brute2fine optimizer in 0.2154231071472168 seconds
# Fitting of 1 voxels complete in 0.022938966751098633 seconds.
# Average of 0.022938966751098633 seconds per voxel.
# Setup brute2fine optimizer in 0.2014608383178711 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.22340154647827148 seconds
# Fitting of 1 voxels complete in 0.0249330997467041 seconds.
# Average of 0.0249330997467041 seconds per voxel.
# Setup brute2fine optimizer in 0.212052583694458 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20894765853881836 seconds
# Fitting of 1 voxels complete in 0.025938749313354492 seconds.
# Average of 0.025938749313354492 seconds per voxel.
# Setup brute2fine optimizer in 0.23038244247436523 seconds
# Fitting of 1 voxels complete in 0.03291201591491699 seconds.
# Average of 0.03291201591491699 seconds per voxel.
# Setup brute2fine optimizer in 0.2314143180847168 seconds
# Fitting of 1 voxels complete in 0.03290867805480957 seconds.
# Average of 0.03290867805480957 seconds per voxel.
# Setup brute2fine optimizer in 0.24290728569030762 seconds
# Fitting of 1 voxels complete in 0.026890039443969727 seconds.
# Average of 0.026890039443969727 seconds per voxel.
# Setup brute2fine optimizer in 0.24299311637878418 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.23436760902404785 seconds
# Fitting of 1 voxels complete in 0.021940231323242188 seconds.
# Average of 0.021940231323242188 seconds per voxel.
# Setup brute2fine optimizer in 0.2263932228088379 seconds
# Fitting of 1 voxels complete in 0.02393651008605957 seconds.
# Average of 0.02393651008605957 seconds per voxel.
# Setup brute2fine optimizer in 0.20445823669433594 seconds
# Fitting of 1 voxels complete in 0.023478269577026367 seconds.
# Average of 0.023478269577026367 seconds per voxel.
# Setup brute2fine optimizer in 0.2035503387451172 seconds
# Fitting of 1 voxels complete in 0.022948503494262695 seconds.
# Average of 0.022948503494262695 seconds per voxel.
# Setup brute2fine optimizer in 0.20343828201293945 seconds
# Fitting of 1 voxels complete in 0.02393651008605957 seconds.
# Average of 0.02393651008605957 seconds per voxel.
# Setup brute2fine optimizer in 0.2039332389831543 seconds
# Fitting of 1 voxels complete in 0.03052234649658203 seconds.
# Average of 0.03052234649658203 seconds per voxel.
# Setup brute2fine optimizer in 0.21688461303710938 seconds
# Fitting of 1 voxels complete in 0.0249330997467041 seconds.
# Average of 0.0249330997467041 seconds per voxel.
# Setup brute2fine optimizer in 0.21043682098388672 seconds
# Fitting of 1 voxels complete in 0.01430511474609375 seconds.
# Average of 0.01430511474609375 seconds per voxel.
# Setup brute2fine optimizer in 0.20846939086914062 seconds
# Fitting of 1 voxels complete in 0.018926143646240234 seconds.
# Average of 0.018926143646240234 seconds per voxel.
# Setup brute2fine optimizer in 0.2054429054260254 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.20682048797607422 seconds
# Fitting of 1 voxels complete in 0.021941184997558594 seconds.
# Average of 0.021941184997558594 seconds per voxel.
# Setup brute2fine optimizer in 0.2014462947845459 seconds
# Fitting of 1 voxels complete in 0.021941423416137695 seconds.
# Average of 0.021941423416137695 seconds per voxel.
# Setup brute2fine optimizer in 0.2084674835205078 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.2036435604095459 seconds
# Fitting of 1 voxels complete in 0.020943641662597656 seconds.
# Average of 0.020943641662597656 seconds per voxel.
# Setup brute2fine optimizer in 0.2074577808380127 seconds
# Fitting of 1 voxels complete in 0.02094411849975586 seconds.
# Average of 0.02094411849975586 seconds per voxel.
# Setup brute2fine optimizer in 0.20147132873535156 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.2074449062347412 seconds
# Fitting of 1 voxels complete in 0.02792525291442871 seconds.
# Average of 0.02792525291442871 seconds per voxel.
# Setup brute2fine optimizer in 0.20546221733093262 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.20795512199401855 seconds
# Fitting of 1 voxels complete in 0.021940946578979492 seconds.
# Average of 0.021940946578979492 seconds per voxel.
# Setup brute2fine optimizer in 0.2034623622894287 seconds
# Fitting of 1 voxels complete in 0.022931814193725586 seconds.
# Average of 0.022931814193725586 seconds per voxel.
# Setup brute2fine optimizer in 0.207444429397583 seconds
# Fitting of 1 voxels complete in 0.022939205169677734 seconds.
# Average of 0.022939205169677734 seconds per voxel.
# Setup brute2fine optimizer in 0.20046377182006836 seconds
# Fitting of 1 voxels complete in 0.0219419002532959 seconds.
# Average of 0.0219419002532959 seconds per voxel.
# Setup brute2fine optimizer in 0.20644760131835938 seconds
# Fitting of 1 voxels complete in 0.02193450927734375 seconds.
# Average of 0.02193450927734375 seconds per voxel.
# Setup brute2fine optimizer in 0.20670366287231445 seconds
# Fitting of 1 voxels complete in 0.027894258499145508 seconds.
# Average of 0.027894258499145508 seconds per voxel.
# Setup brute2fine optimizer in 0.20096802711486816 seconds
# Fitting of 1 voxels complete in 0.01752161979675293 seconds.
# Average of 0.01752161979675293 seconds per voxel.
# Setup brute2fine optimizer in 0.2079455852508545 seconds
# Fitting of 1 voxels complete in 0.02792978286743164 seconds.
# ...
# Fitting of 1 voxels complete in 0.026941299438476562 seconds.
# Average of 0.026941299438476562 seconds per voxel.
# Setup brute2fine optimizer in 0.20544958114624023 seconds
# Fitting of 1 voxels complete in 0.025940656661987305 seconds.
# Average of 0.025940656661987305 seconds per voxel.
# Setup brute2fine optimizer in 0.20244669914245605 seconds
# Fitting of 1 voxels complete in 0.02692866325378418 seconds.
# Average of 0.02692866325378418 seconds per voxel.
# Setup brute2fine optimizer in 0.21193814277648926 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.2373654842376709 seconds
# Fitting of 1 voxels complete in 0.020964860916137695 seconds.
# Average of 0.020964860916137695 seconds per voxel.
# Setup brute2fine optimizer in 0.19844627380371094 seconds
# Fitting of 1 voxels complete in 0.022938966751098633 seconds.
# Average of 0.022938966751098633 seconds per voxel.
# Setup brute2fine optimizer in 0.20743393898010254 seconds
# Fitting of 1 voxels complete in 0.03091740608215332 seconds.
# Average of 0.03091740608215332 seconds per voxel.
# Setup brute2fine optimizer in 0.20396924018859863 seconds
# Fitting of 1 voxels complete in 0.019986867904663086 seconds.
# Average of 0.019986867904663086 seconds per voxel.
# Setup brute2fine optimizer in 0.20144438743591309 seconds
# Fitting of 1 voxels complete in 0.029920101165771484 seconds.
# Average of 0.029920101165771484 seconds per voxel.
# Setup brute2fine optimizer in 0.21043682098388672 seconds
# Fitting of 1 voxels complete in 0.023915529251098633 seconds.
# Average of 0.023915529251098633 seconds per voxel.
# Setup brute2fine optimizer in 0.20745611190795898 seconds
# Fitting of 1 voxels complete in 0.02892303466796875 seconds.
# Average of 0.02892303466796875 seconds per voxel.
# Setup brute2fine optimizer in 0.20994353294372559 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20943808555603027 seconds
# Fitting of 1 voxels complete in 0.025930166244506836 seconds.
# Average of 0.025930166244506836 seconds per voxel.
# Setup brute2fine optimizer in 0.2034447193145752 seconds
# Fitting of 1 voxels complete in 0.023929595947265625 seconds.
# Average of 0.023929595947265625 seconds per voxel.
# Setup brute2fine optimizer in 0.2044525146484375 seconds
# Fitting of 1 voxels complete in 0.020943641662597656 seconds.
# Average of 0.020943641662597656 seconds per voxel.
# Setup brute2fine optimizer in 0.20496010780334473 seconds
# Fitting of 1 voxels complete in 0.027925491333007812 seconds.
# Average of 0.027925491333007812 seconds per voxel.
# Setup brute2fine optimizer in 0.20744538307189941 seconds
# Fitting of 1 voxels complete in 0.020943641662597656 seconds.
# Average of 0.020943641662597656 seconds per voxel.
# Setup brute2fine optimizer in 0.21669363975524902 seconds
# Fitting of 1 voxels complete in 0.031957387924194336 seconds.
# Average of 0.031957387924194336 seconds per voxel.
# Setup brute2fine optimizer in 0.21146392822265625 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.20345544815063477 seconds
# Fitting of 1 voxels complete in 0.03059077262878418 seconds.
# Average of 0.03059077262878418 seconds per voxel.
# Setup brute2fine optimizer in 0.20545029640197754 seconds
# Fitting of 1 voxels complete in 0.0219419002532959 seconds.
# Average of 0.0219419002532959 seconds per voxel.
# Setup brute2fine optimizer in 0.2049572467803955 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20346689224243164 seconds
# Fitting of 1 voxels complete in 0.02692556381225586 seconds.
# Average of 0.02692556381225586 seconds per voxel.
# Setup brute2fine optimizer in 0.20395970344543457 seconds
# Fitting of 1 voxels complete in 0.026923656463623047 seconds.
# Average of 0.026923656463623047 seconds per voxel.
# Setup brute2fine optimizer in 0.20545005798339844 seconds
# Fitting of 1 voxels complete in 0.023937225341796875 seconds.
# Average of 0.023937225341796875 seconds per voxel.
# Setup brute2fine optimizer in 0.20543813705444336 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.2084646224975586 seconds
# Fitting of 1 voxels complete in 0.022927284240722656 seconds.
# Average of 0.022927284240722656 seconds per voxel.
# Setup brute2fine optimizer in 0.20510387420654297 seconds
# Fitting of 1 voxels complete in 0.0239713191986084 seconds.
# Average of 0.0239713191986084 seconds per voxel.
# Setup brute2fine optimizer in 0.20687007904052734 seconds
# Fitting of 1 voxels complete in 0.02991962432861328 seconds.
# Average of 0.02991962432861328 seconds per voxel.
# Setup brute2fine optimizer in 0.2134084701538086 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.2059004306793213 seconds
# Fitting of 1 voxels complete in 0.022938966751098633 seconds.
# Average of 0.022938966751098633 seconds per voxel.
# Setup brute2fine optimizer in 0.21143507957458496 seconds
# Fitting of 1 voxels complete in 0.023935556411743164 seconds.
# Average of 0.023935556411743164 seconds per voxel.
# Setup brute2fine optimizer in 0.2044529914855957 seconds
# Fitting of 1 voxels complete in 0.025923728942871094 seconds.
# Average of 0.025923728942871094 seconds per voxel.
# Setup brute2fine optimizer in 0.20695185661315918 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20744800567626953 seconds
# Fitting of 1 voxels complete in 0.024933576583862305 seconds.
# Average of 0.024933576583862305 seconds per voxel.
# Setup brute2fine optimizer in 0.2049570083618164 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.2044532299041748 seconds
# Fitting of 1 voxels complete in 0.021941423416137695 seconds.
# Average of 0.021941423416137695 seconds per voxel.
# Setup brute2fine optimizer in 0.2154076099395752 seconds
# Fitting of 1 voxels complete in 0.026927709579467773 seconds.
# Average of 0.026927709579467773 seconds per voxel.
# Setup brute2fine optimizer in 0.20545029640197754 seconds
# Fitting of 1 voxels complete in 0.021941423416137695 seconds.
# Average of 0.021941423416137695 seconds per voxel.
# Setup brute2fine optimizer in 0.206953763961792 seconds
# Fitting of 1 voxels complete in 0.025930404663085938 seconds.
# Average of 0.025930404663085938 seconds per voxel.
# Setup brute2fine optimizer in 0.2029581069946289 seconds
# Fitting of 1 voxels complete in 0.022938966751098633 seconds.
# Average of 0.022938966751098633 seconds per voxel.
# Setup brute2fine optimizer in 0.207122802734375 seconds
# Fitting of 1 voxels complete in 0.02244091033935547 seconds.
# Average of 0.02244091033935547 seconds per voxel.
# Setup brute2fine optimizer in 0.21497225761413574 seconds
# Fitting of 1 voxels complete in 0.023935556411743164 seconds.
# Average of 0.023935556411743164 seconds per voxel.
# Setup brute2fine optimizer in 0.20345568656921387 seconds
# Fitting of 1 voxels complete in 0.024916887283325195 seconds.
# Average of 0.024916887283325195 seconds per voxel.
# Setup brute2fine optimizer in 0.21146821975708008 seconds
# Fitting of 1 voxels complete in 0.020910024642944336 seconds.
# Average of 0.020910024642944336 seconds per voxel.
# Setup brute2fine optimizer in 0.21031522750854492 seconds
# Fitting of 1 voxels complete in 0.021941423416137695 seconds.
# Average of 0.021941423416137695 seconds per voxel.
# Setup brute2fine optimizer in 0.2044525146484375 seconds
# Fitting of 1 voxels complete in 0.024438858032226562 seconds.
# Average of 0.024438858032226562 seconds per voxel.
# Setup brute2fine optimizer in 0.20931601524353027 seconds
# Fitting of 1 voxels complete in 0.03091597557067871 seconds.
# Average of 0.03091597557067871 seconds per voxel.
# Setup brute2fine optimizer in 0.20844244956970215 seconds
# Fitting of 1 voxels complete in 0.026927947998046875 seconds.
# Average of 0.026927947998046875 seconds per voxel.
# Setup brute2fine optimizer in 0.20445632934570312 seconds
# Fitting of 1 voxels complete in 0.027925729751586914 seconds.
# Average of 0.027925729751586914 seconds per voxel.
# Setup brute2fine optimizer in 0.2106313705444336 seconds
# Fitting of 1 voxels complete in 0.024932384490966797 seconds.
# Average of 0.024932384490966797 seconds per voxel.
# Setup brute2fine optimizer in 0.20389127731323242 seconds
# Fitting of 1 voxels complete in 0.021941184997558594 seconds.
# Average of 0.021941184997558594 seconds per voxel.
# Setup brute2fine optimizer in 0.2044534683227539 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.21143388748168945 seconds
# Fitting of 1 voxels complete in 0.021934986114501953 seconds.
# Average of 0.021934986114501953 seconds per voxel.
# Setup brute2fine optimizer in 0.21043705940246582 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.2044527530670166 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20644760131835938 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20842909812927246 seconds
# Fitting of 1 voxels complete in 0.025930404663085938 seconds.
# Average of 0.025930404663085938 seconds per voxel.
# Setup brute2fine optimizer in 0.20345544815063477 seconds
# Fitting of 1 voxels complete in 0.01994633674621582 seconds.
# Average of 0.01994633674621582 seconds per voxel.
# Setup brute2fine optimizer in 0.22292327880859375 seconds
# Fitting of 1 voxels complete in 0.01795220375061035 seconds.
# Average of 0.01795220375061035 seconds per voxel.
# Setup brute2fine optimizer in 0.19997048377990723 seconds
# Fitting of 1 voxels complete in 0.02293872833251953 seconds.
# Average of 0.02293872833251953 seconds per voxel.
# Setup brute2fine optimizer in 0.2343733310699463 seconds
# Fitting of 1 voxels complete in 0.024933815002441406 seconds.
# Average of 0.024933815002441406 seconds per voxel.
# Setup brute2fine optimizer in 0.20644736289978027 seconds
# Fitting of 1 voxels complete in 0.024932384490966797 seconds.
# Average of 0.024932384490966797 seconds per voxel.
# Setup brute2fine optimizer in 0.20844149589538574 seconds
# Fitting of 1 voxels complete in 0.029919862747192383 seconds.
# Average of 0.029919862747192383 seconds per voxel.
# Setup brute2fine optimizer in 0.20844197273254395 seconds
# Fitting of 1 voxels complete in 0.026928424835205078 seconds.
# Average of 0.026928424835205078 seconds per voxel.
# Setup brute2fine optimizer in 0.20644712448120117 seconds
# Fitting of 1 voxels complete in 0.03390979766845703 seconds.
# Average of 0.03390979766845703 seconds per voxel.
# Setup brute2fine optimizer in 0.21259403228759766 seconds
# Fitting of 1 voxels complete in 0.030916452407836914 seconds.
# Average of 0.030916452407836914 seconds per voxel.
# Setup brute2fine optimizer in 0.2080078125 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.21941637992858887 seconds
# Fitting of 1 voxels complete in 0.025931119918823242 seconds.
# Average of 0.025931119918823242 seconds per voxel.
# Setup brute2fine optimizer in 0.2290194034576416 seconds
# Fitting of 1 voxels complete in 0.024968862533569336 seconds.
# Average of 0.024968862533569336 seconds per voxel.
# Setup brute2fine optimizer in 0.21242642402648926 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20338964462280273 seconds
# Fitting of 1 voxels complete in 0.0226590633392334 seconds.
# Average of 0.0226590633392334 seconds per voxel.
# Setup brute2fine optimizer in 0.21097731590270996 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.20348119735717773 seconds
# Fitting of 1 voxels complete in 0.025931119918823242 seconds.
# Average of 0.025931119918823242 seconds per voxel.
# Setup brute2fine optimizer in 0.2053062915802002 seconds
# Fitting of 1 voxels complete in 0.020943880081176758 seconds.
# Average of 0.020943880081176758 seconds per voxel.
# Setup brute2fine optimizer in 0.21043729782104492 seconds
# Fitting of 1 voxels complete in 0.027923583984375 seconds.
# Average of 0.027923583984375 seconds per voxel.
# Setup brute2fine optimizer in 0.20543766021728516 seconds
# Fitting of 1 voxels complete in 0.020943880081176758 seconds.
# Average of 0.020943880081176758 seconds per voxel.
# Setup brute2fine optimizer in 0.212418794631958 seconds
# Fitting of 1 voxels complete in 0.018945932388305664 seconds.
# Average of 0.018945932388305664 seconds per voxel.
# Setup brute2fine optimizer in 0.20943951606750488 seconds
# Fitting of 1 voxels complete in 0.02293848991394043 seconds.
# Average of 0.02293848991394043 seconds per voxel.
# Setup brute2fine optimizer in 0.21342873573303223 seconds
# Fitting of 1 voxels complete in 0.02492666244506836 seconds.
# Average of 0.02492666244506836 seconds per voxel.
# Setup brute2fine optimizer in 0.20844244956970215 seconds
# Fitting of 1 voxels complete in 0.021941661834716797 seconds.
# Average of 0.021941661834716797 seconds per voxel.
# Setup brute2fine optimizer in 0.20943951606750488 seconds
# Fitting of 1 voxels complete in 0.023936033248901367 seconds.
# Average of 0.023936033248901367 seconds per voxel.
# Setup brute2fine optimizer in 0.2044353485107422 seconds
# Fitting of 1 voxels complete in 0.027925491333007812 seconds.
# Average of 0.027925491333007812 seconds per voxel.
# Setup brute2fine optimizer in 0.2044532299041748 seconds
# Fitting of 1 voxels complete in 0.026928186416625977 seconds.
# Average of 0.026928186416625977 seconds per voxel.
# Setup brute2fine optimizer in 0.20643329620361328 seconds
# Fitting of 1 voxels complete in 0.031914710998535156 seconds.
# Average of 0.031914710998535156 seconds per voxel.
# Setup brute2fine optimizer in 0.2044527530670166 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20345401763916016 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20345568656921387 seconds
# Fitting of 1 voxels complete in 0.02393627166748047 seconds.
# Average of 0.02393627166748047 seconds per voxel.
# Setup brute2fine optimizer in 0.20844244956970215 seconds
# Fitting of 1 voxels complete in 0.02892279624938965 seconds.
# Average of 0.02892279624938965 seconds per voxel.
# Setup brute2fine optimizer in 0.2064366340637207 seconds
# Fitting of 1 voxels complete in 0.02496170997619629 seconds.
# Average of 0.02496170997619629 seconds per voxel.
# Setup brute2fine optimizer in 0.21143317222595215 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.20344257354736328 seconds
# Fitting of 1 voxels complete in 0.024933338165283203 seconds.
# Average of 0.024933338165283203 seconds per voxel.
# Setup brute2fine optimizer in 0.21143412590026855 seconds
# Fitting of 1 voxels complete in 0.026928186416625977 seconds.
# Average of 0.026928186416625977 seconds per voxel.
# Setup brute2fine optimizer in 0.20545029640197754 seconds
# Fitting of 1 voxels complete in 0.020943880081176758 seconds.
# Average of 0.020943880081176758 seconds per voxel.
# Fitting accuracy:
# MSE +/- STD = 0.003143 +/- 0.001678

# %% [markdown]
# The MSEs and STDs are much lower than before. Also, the visualization of fiber bundles looks more realistic.

# %%
print("state-of-the-art model:")
visualize_result(reference_bas_model)
# Out:
# state-of-the-art model:

# %% [markdown]
# ### Assignment
#
# Use any optimization engine that you know (e.g. genetic algorithm) and compare your results with the state-of-the-art solution.
# - Can your solution produce more exact fitting?
# - Are the MSEs less dispersed?
# - Does it work faster than the reference method?

# %%
def domain_dict_to_array(d):
    domains_dict = d
    domains_list = np.array(list(domains_dict.values()))
    domains_array = np.array(domains_list[0][0])
    domains_array = np.vstack((domains_array, domains_list[0][1]))
    domains_array = np.vstack((domains_array, domains_list[1]))
    domains_array = np.vstack((domains_array, domains_list[2]))
    domains_array = np.vstack((domains_array, domains_list[3]))
    domains_array = np.vstack((domains_array, domains_list[4]))
    return domains_array

# %%
bas_model.parameter_ranges
# Out:
# OrderedDict([('C1Stick_1_mu',
#               ([0, 3.141592653589793],
#                [-3.141592653589793, 3.141592653589793])),
#              ('C1Stick_1_lambda_par', (0.1, 3)),
#              ('G1Ball_1_lambda_iso', (0.1, 3)),
#              ('partial_volume_0', (0.01, 0.99)),
#              ('partial_volume_1', (0.01, 0.99))])

# %%
domain_dict_to_array(bas_model.parameter_ranges)
# Out:
# array([[0.0, 3.141592653589793],
#        [-3.141592653589793, 3.141592653589793],
#        [0.1, 3],
#        [0.1, 3],
#        [0.01, 0.99],
#        [0.01, 0.99]], dtype=object)

# %%
# 6 values per voxel so x * y * 6 in chromosome

# %%
x_me, y_me = 20, 20
chromosome_example = np.zeros((x_me, y_me, 6))
print(chromosome_example.shape)
# Out:
# (20, 20, 6)

# %%
def array_to_dict(a):
    d = bas_model.parameter_ranges
    fd = {}
    fd['C1Stick_1_mu'] = a[0]
    fd['C1Stick_1_lambda_par'] = a[1]
    fd['G1Ball_1_lambda_iso'] = a[1]
    fd['partial_volume_0'] = a[1]
    fd['partial_volume_1'] = a[1]
    return fd

# %%
chro1 = chromosome_example[0][0]
array_to_dict(chro1)
# Out:
# {'C1Stick_1_mu': 0.0,
#  'C1Stick_1_lambda_par': 0.0,
#  'G1Ball_1_lambda_iso': 0.0,
#  'partial_volume_0': 0.0,
#  'partial_volume_1': 0.0}

# %%
def es(objective_function, chromosome_length, population_size, number_of_iterations, number_of_offspring, number_of_parents, sigma, tau, tau_0, log_frequency=1, R=None):

    best_solution = np.empty((1, chromosome_length))
    best_solution_objective_value = 0.00

    log_objective_values = np.empty((number_of_iterations, 4))
    log_best_solutions = np.empty((number_of_iterations, chromosome_length))
    log_best_sigmas = np.empty((number_of_iterations, chromosome_length))
    
    def mut3(og):
        S = np.random.uniform(0,0.5, size=(chromosome_length, chromosome_length))
        S = np.dot(S,S.T)
        return og + np.dot(np.random.randn(number_of_offspring, chromosome_length), np.linalg.cholesky(S).T)
    
    mutation_f = mut3

    # generating an initial population
    current_population_solutions = 100.0 * np.random.rand(population_size, chromosome_length)
    current_population_sigmas = sigma * np.ones((population_size, chromosome_length))

    # evaluating the objective function on the current population
    current_population_objective_values = objective_function(current_population_solutions)

    for t in range(number_of_iterations):

        # selecting the parent indices by the roulette wheel method
        fitness_values = current_population_objective_values - current_population_objective_values.min()
        if fitness_values.sum() > 0:
            fitness_values = fitness_values / fitness_values.sum()
        else:
            fitness_values = 1.0 / population_size * np.ones(population_size)
        parent_indices = np.random.choice(population_size, (number_of_offspring, number_of_parents), True, fitness_values).astype(np.int64)

        # creating the children population by Global Intermediere Recombination
        children_population_solutions = np.zeros((number_of_offspring, chromosome_length))
        children_population_sigmas = np.zeros((number_of_offspring, chromosome_length))
        for i in range(number_of_offspring):
            children_population_solutions[i, :] = current_population_solutions[parent_indices[i, :], :].mean(axis=0)
            children_population_sigmas[i, :] = current_population_sigmas[parent_indices[i, :], :].mean(axis=0)

        # mutating the children population by adding random gaussian noise
        children_population_solutions = mutation_f(children_population_solutions)
    
        # checking if in domain
        if R != None:
            for j, child in enumerate(current_population_solutions):
                for c,chrom in enumerate(child):
                    if not R[c][0] < chrom < R[c][1]:
                        current_population_solutions[j][c] = np.random.uniform(R[c][0], R[c][1])
                        
                        
        # checking if in domain
        if R != None:
            for j, child in enumerate(children_population_solutions):
                for c,chrom in enumerate(child):
                    if not R[c][0] < chrom < R[c][1]:
                        children_population_solutions[j][c] = np.random.uniform(R[c][0], R[c][1])
        
        # evaluating the objective function on the children population
        children_population_objective_values = objective_function(children_population_solutions)

        # replacing the current population by (Mu + Lambda) Replacement
        current_population_objective_values = np.hstack([current_population_objective_values, children_population_objective_values])
        current_population_solutions = np.vstack([current_population_solutions, children_population_solutions])
        current_population_sigmas = np.vstack([current_population_sigmas, children_population_sigmas])

        I = np.argsort(current_population_objective_values)[::-1]
        current_population_solutions = current_population_solutions[I[:population_size], :]
        current_population_sigmas = current_population_sigmas[I[:population_size], :]
        current_population_objective_values = current_population_objective_values[I[:population_size]]

        # recording some statistics
        if best_solution_objective_value < current_population_objective_values[0]:
            best_solution = current_population_solutions[0, :]
            best_solution_objective_value = current_population_objective_values[0]
        log_objective_values[t, :] = [current_population_objective_values.min(), current_population_objective_values.max(), current_population_objective_values.mean(), current_population_objective_values.std()]
        log_best_solutions[t, :] = current_population_solutions[0, :]
        log_best_sigmas[t, :] = current_population_sigmas[0, :]
        
        if log_frequency != -1 and np.mod(t, log_frequency) == 0:
            print("Iteration %04d : best score = %0.8f, mean score = %0.8f." % (t, log_objective_values[:t+1, 1].max(), log_objective_values[t, 2]))

    return best_solution_objective_value, best_solution, log_objective_values, log_best_solutions, log_best_sigmas

# %%
def plot_values(history_objective_values, history_best_sigmas): 
    plt.figure(figsize=(18, 4))
    plt.plot(history_objective_values[:, 0], 'g-',label='min')
    plt.plot(history_objective_values[:, 1], 'r-',label='max')
    plt.plot(history_objective_values[:, 2], 'b-',label='avg')
    plt.legend()
    plt.xlabel('iteration')
    plt.ylabel('objective function value')
    plt.title('min/avg/max objective function values')
    plt.show()

# %%
def set_random_parameters(our_voxel_bas_model, scheme_hcp, voxel_signal):
    params = []

    # estimate S0
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    # G1Ball_1_lambda_iso
    param_range = our_voxel_bas_model.parameter_ranges['G1Ball_1_lambda_iso']
    lambda_iso = np.random.uniform(param_range[0], param_range[1]) * 1e-09

    # C1Stick_1_mu
    param_ranges = our_voxel_bas_model.parameter_ranges['C1Stick_1_mu']
    mu_1 = np.random.uniform(param_ranges[0][0], param_ranges[0][1])
    mu_2 = np.random.uniform(param_ranges[1][0], param_ranges[1][1])
    
    # C1Stick_1_lambda_par
    param_range = our_voxel_bas_model.parameter_ranges['C1Stick_1_lambda_par']
    lambda_parallel = np.random.uniform(param_range[0], param_range[1]) * 1e-09
    
    # partial_volume_0
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_0']
    f_stick = np.random.uniform(param_range[0], param_range[1])
    
    # partial_volume_1
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_1']
    f_ball = np.random.uniform(param_range[0], param_range[1])
            
    return FittedMultiCompartmentModel(
        our_voxel_bas_model, np.array(S0), np.array([True]), 
        np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )


def set_params_from_chrom(chrom, our_voxel_bas_model, scheme_hcp, voxel_signal):
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    return FittedMultiCompartmentModel(
            our_voxel_bas_model, np.array(S0), np.array([True]), 
            np.array([chrom])
        )

def objective_function(ch, bas_model, scheme_hcp, voxel_signal):
    our_bas_model = {}
    voxel_mse = np.zeros([roi['width'], roi['height']])

    for x in range(roi['width']):
        our_bas_model[x] = {}
        for y in range(roi['height']):

            voxel_signal = data_hcp_roi[x, 0, y, :]
            our_bas_model[x][y] = set_params_from_chrom(ch, bas_model, scheme_hcp, voxel_signal)

            voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

    return np.mean(voxel_mse)

# %%
d = 6 * 20 * 20
N = 100
T = 20

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
    lambda ch: objective_function(ch, bas_model, scheme_hcp, voxel_signal), d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10, R=None)

plot_values(history_objective_values, history_best_sigmas)
# Out:
# We highly recommend installing numba for faster function execution and model fitting.
# We highly recommend installing pathos to take advantage of multicore processing.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e0c22552ace7> in <module>
#       7 bas_model = MultiCompartmentModel(models=[stick, ball])
#       8
# ----> 9 best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
#      10     lambda ch: objective_function(ch, bas_model, scheme_hcp, voxel_signal), d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10, R=None)
#      11
#
# <ipython-input-40-67cb256db864> in es(objective_function, chromosome_length, population_size, number_of_iterations, number_of_offspring, number_of_parents, sigma, tau, tau_0, log_frequency, R)
#      20
#      21     # evaluating the objective function on the current population
# ---> 22     current_population_objective_values = objective_function(current_population_solutions)
#      23
#      24     for t in range(number_of_iterations):
#
# <ipython-input-47-e0c22552ace7> in <lambda>(ch)
#       8
#       9 best_objective_value, best_chromosome, history_objective_values, history_best_chromosome, history_best_sigmas = es(
# ---> 10     lambda ch: objective_function(ch, bas_model, scheme_hcp, voxel_signal), d, N, T, 2*N, 2, 50.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 10, R=None)
#      11
#      12 plot_values(history_objective_values, history_best_sigmas)
#
# <ipython-input-46-d09758461232> in objective_function(ch, bas_model, scheme_hcp, voxel_signal)
#      53             our_bas_model[x][y] = set_params_from_chrom(ch, bas_model, scheme_hcp, voxel_signal)
#      54
# ---> 55             voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)
#      56
#      57     return np.mean(voxel_mse)
#
# c:\users\krzys\appdata\local\programs\python\python38\lib\site-packages\dmipy\core\fitted_modeling_framework.py in mean_squared_error(self, data)
#     265             data_ = data / self.S0
#     266
# --> 267         y_hat = self.predict(S0=1.)
#     268         mse = np.mean((data_ - y_hat) ** 2, axis=-1)
#     269         mse[~self.mask] = 0
#
# c:\users\krzys\appdata\local\programs\python\python38\lib\site-packages\dmipy\core\fitted_modeling_framework.py in predict(self, acquisition_scheme, S0, mask)
#     242             parameters = self.model.parameter_vector_to_parameters(
#     243                 self.fitted_parameters_vector[pos])
# --> 244             predicted_signal[pos] = self.model(
#     245                 acquisition_scheme, **parameters) * S0[pos]
#     246         return predicted_signal
#
# c:\users\krzys\appdata\local\programs\python\python38\lib\site-packages\dmipy\core\modeling_framework.py in __call__(self, acquisition_scheme_or_vertices, quantity, **kwargs)
#    1342                 values = (
#    1343                     values +
# -> 1344                     partial_volume * model(
#    1345                         acquisition_scheme_or_vertices, **parameters)
#    1346                 )
#
# c:\users\krzys\appdata\local\programs\python\python38\lib\site-packages\dmipy\signal_models\cylinder_models.py in __call__(self, acquisition_scheme, **kwargs)
#      88         lambda_par_ = kwargs.get('lambda_par', self.lambda_par)
#      89         mu = kwargs.get('mu', self.mu)
# ---> 90         mu = utils.unitsphere2cart_1d(mu)
#      91         E_stick = _attenuation_parallel_stick(bvals, lambda_par_, n, mu)
#      92         return E_stick
#
# c:\users\krzys\appdata\local\programs\python\python38\lib\site-packages\dmipy\utils\utils.py in unitsphere2cart_1d(mu)
#     422         mu in cartesian coordinates, as x, y, z = mu_cart
#     423     """
# --> 424     theta, phi = mu
#     425     mu_cart = np.zeros(3)
#     426     sintheta = np.sin(theta)
#
# ValueError: too many values to unpack (expected 2)

# %%
scheme_hcp
