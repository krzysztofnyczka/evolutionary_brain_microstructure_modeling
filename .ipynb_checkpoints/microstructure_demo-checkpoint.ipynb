# %% [markdown]
# # Evolutionary Algorithms in Brain Microstructure Modeling

# %% [markdown]
# ## Magnetic Resonance Imaging (MRI)
#
# MRI allows to acquire images of living tissue, e.g. human brain. Typically, every image voxel represents a cubic volume of dimensions from 1x1x1 [mm] to 2x2x2 [mm], depending on MRI scanner parameters. Such resolution allows for instance to delineate grey and white matter tissue, as illustrated below.
# <br /><br />
#
# <div align="center">
#    <img src="hcp_sample_t1.png" width="80%" />
#    sample T1-weighted image,
#    <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# <strong>Grey matter</strong> comprises of densely packed neuronal bodies, whereas <strong>white matter</strong> is formed of axons and dendrites aligned in fiber bundles. The bundles play a role of neuronal connections between distant grey matter areas, resembling a network of "highways" inside the brain.
# <br /><br />
#
# <div align="center">
#    <img src="white_matter_tracts.png" width="80%" />
#    sample white matter tracts,
#    <em>source: https://radiologykey.com/white-matter-tracts/</em>
# </div>
#
# <br />

# %% [markdown]
# ## Diffusion Weighted Imaging (DWI)
#
# DWI is an imaging technique that captures mean displacement of water molecules in specified 3D directions, e.g. left-right, front-rear, top-bottom:
# <br /><br />
#
# <div align="center">
#     <img src="hcp_sample_dwi.png" width="80%" />
#     sample DWI-weighted images,
#     <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# Areas of <strong>high diffusivity</strong> are represented with darkest shades on diffusion weighted images. In the example above, the diffusivity in X direction (i.e. left-right) dominates the other two directions inside the highlighed region.
# <br /><br />
#
# We know (from physics and neuroanatomy) that water inside white matter "prefers" to diffuse along fibers rather than perpendicularly. With this in mind, DWI offers us an opportunity to capture anatomical features hidden below nominal imaging resolution. In particular, post processing of diffusion weighted images gives us spacial orientations of fibers inside each voxel containing white matter.
# <br /><br />
#
# <div align="center">
#     <img src="ball_and_stick_fitted.png" width="60%" />
#     orientations of fiber bundles in a sample region of white matter,
#     <em>source: Human Connectome Project</em>
# </div>
# <br />
#
# Further postprocessing allows to obtain <strong>tractogram</strong> which is a color-coded map of neuronal connections inside the brain. Currently, tractograms are used both in research (e.g. neuroscience) and clinical practice (e.g. pre-surgical planning).
# <br /><br />
#
# <div align="center">
#     <img src="tractogram.jpg" width="80%" />
#     sample tractogram,
#     <em>source: http://mcgovern.mit.edu/news/images/brain-scan-cover-image-summer-2013/</em>
# </div>
#
# <br />

# %% [markdown]
# ## Microstructure modeling
#
# In practice, diffusion signal is acquired from many directions and with various imaging settings. Protocols used by clinicians comprise of at least 32 images, whereas data sets processed by researchers contain even hundreds of diffusion weighted images per subject. Generally, the more images we have, the more exactly we can estimate microstructure features inside voxels.
# <br /><br />
#
# <div align="center">
#     <img src="dwi_imaging_directions.png" width="40%" />
#     sample map of imaging directions,
#     <em>source: http://www.emmanuelcaruyer.com/q-space-sampling.php</em>
# </div>
# <br />
#
# In order to process diffusion weighted images, we need a mathematical model that would fit the measured signal. One of the simplest models of this type is called <strong>Ball and Stick</strong>. The <em>ball</em> part of this model represents diffusion of extra-cellular water (that is not interesting for us now), whereas the <em>stick</em> part represents intra-cellular diffusion of water trapped inside axons.
# <br /><br />
#
# <div align="center">
#     <img src="ball_and_stick_illustration.png" width="80%" />
#     sample ball and stick configurations inside voxels
# </div>
# <br />

# %% [markdown]
# ### Ball and Stick - formal definition
#
# Let $M$ > 0 be the number of diffusion weighted images. For all $k = 1, ..., M$, the signal is modelled as
# <br /><br />
#
# <div align="center">
# $S_k = S_0 \left[ f_{ball} \cdot \exp \left(-b_k \lambda_{iso} (\mathbf{g}_k^T \mathbf{v})^2 \right) + f_{stick} \cdot \exp(-b_k \lambda_{\parallel}) \right]$,
# </div>
#
# where:
#
# - $f_{ball}, f_{stick} \in (0, 1)$ are weighing parameters of ball and stick fractions respectively,
# - $\lambda_{iso} \in \mathbb{R}$ is an isotropic diffusivity (inside the ball),
# - $\lambda_{parallel} \in \mathbb{R}$ is a parallel diffusivity (inside the stick),
# - $v = [\sin\mu_1 \cos\mu_2, \sin\mu_1 \sin\mu_2, \cos\mu_1]^T$ is a stick direction with $\mu = (\mu_1, \mu_2) \in [0, \pi] \times [0, 2\pi)$.
# - $S_0$ is the signal acquired without diffusion sensitizing gradient (given),
# - $\mathbf{g_k} \in \mathbb{R}_+^3$ and $b_k \in \mathbb{R}_+$ are the acquisition parameters (given).

# %% [markdown]
# ## Simple example
#
# The source code of this example requires <strong>dmipy</strong> module https://github.com/AthenaEPI/dmipy with its dependencies:
# - numpy >= 1.13
# - scipy
# - dipy
# - nibabel
# - cvxpy
# - fury

# %%
# %%time

import nibabel as nib
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
# %matplotlib inline

import dmipy.data.saved_acquisition_schemes as saved_acquisition_schemes

from dmipy.signal_models import cylinder_models, gaussian_models
from dmipy.core.modeling_framework import MultiCompartmentModel
from dmipy.core.fitted_modeling_framework import FittedMultiCompartmentModel

from dipy.viz import window, actor

import tqdm

import warnings
warnings.filterwarnings("ignore")
# Out:
# Wall time: 971 µs

# %%
import numba
import pathos

# %% [markdown]
# First, we load a sample slice of DWI data from the Human Connectome Project repository: https://www.humanconnectome.org/

# %%
data_hcp = nib.load('wu_minn_hcp_coronal_slice.nii.gz').get_data()
scheme_hcp = saved_acquisition_schemes.wu_minn_hcp_acquisition_scheme()

# %% [markdown]
# We define a rectangular Region Of Interest (ROI):

# %%
roi = {'x': 70, 'y': 70, 'width': 20, 'height': 20}
data_hcp_roi = data_hcp[
    roi['x'] : roi['x'] + roi['width'], :, roi['y'] : roi['y'] + roi['height']
]

fig, ax = plt.subplots(figsize=[10, 10])
ax.imshow(data_hcp[:, 0, :, 0].T, origin='lower', cmap='gray', interpolation='nearest')

rect = patches.Rectangle(
    (roi['x'], roi['y']), roi['width'], roi['height'], 
    linewidth = 3, edgecolor = 'r', facecolor = 'none'
)
ax.add_patch(rect)
ax.set_axis_off()
ax.set_title('Coronal slice with ROI');

# %% [markdown]
# Next, we create an instance of the Ball and Stick diffusion model.

# %%
ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# %% [markdown]
# Our model requires fitting the following five parameters for every image voxel:
# - G1Ball_1_lambda_iso – extra-cellular diffusivity coefficient (real value * $10^{-9}$),
# - C1Stick_1_mu – direction of a stick (2-dimensional real vector of sphere coordinates),
# - C1Stick_1_lambda_par – intra-cellular diffusivity coefficient (real value * $10^{-9}$),
# - partial_volume_0 – weight of the intra-cellular diffusion fraction (real value),
# - partial_volume_1 – weight of the extra-cellular diffusion fraction (real value).
#
# The ranges of parameters are given below:

# %%
bas_model.parameter_ranges
# Out:
# OrderedDict([('C1Stick_1_mu',
#               ([0, 3.141592653589793],
#                [-3.141592653589793, 3.141592653589793])),
#              ('C1Stick_1_lambda_par', (0.1, 3)),
#              ('G1Ball_1_lambda_iso', (0.1, 3)),
#              ('partial_volume_0', (0.01, 0.99)),
#              ('partial_volume_1', (0.01, 0.99))])

# %% [markdown]
# ### Dummy solution
#
# Let's try setting random parameters to our Ball and Stick model.

# %%
def set_parameters(our_voxel_bas_model, scheme_hcp, voxel_signal):
    params = []

    # estimate S0
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    # G1Ball_1_lambda_iso
    param_range = our_voxel_bas_model.parameter_ranges['G1Ball_1_lambda_iso']
    lambda_iso = np.random.uniform(param_range[0], param_range[1]) * 1e-09

    # C1Stick_1_mu
    param_ranges = our_voxel_bas_model.parameter_ranges['C1Stick_1_mu']
    mu_1 = np.random.uniform(param_ranges[0][0], param_ranges[0][1])
    mu_2 = np.random.uniform(param_ranges[1][0], param_ranges[1][1])
    
    # C1Stick_1_lambda_par
    param_range = our_voxel_bas_model.parameter_ranges['C1Stick_1_lambda_par']
    lambda_parallel = np.random.uniform(param_range[0], param_range[1]) * 1e-09
    
    # partial_volume_0
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_0']
    f_stick = np.random.uniform(param_range[0], param_range[1])
    
    # partial_volume_1
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_1']
    f_ball = np.random.uniform(param_range[0], param_range[1])
            
    return FittedMultiCompartmentModel(
        our_voxel_bas_model, np.array(S0), np.array([True]), 
        np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    our_bas_model[x] = {}
    for y in range(roi['height']):
        
        voxel_signal = data_hcp_roi[x, 0, y, :]
        our_bas_model[x][y] = set_parameters(bas_model, scheme_hcp, voxel_signal)
        
        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)
          
print("Fitting accuracy:")        
print("MSE +/- STD = %f +/- %f" % (np.mean(voxel_mse), np.std(voxel_mse)))
# Out:
# Fitting accuracy:
# MSE +/- STD = 0.106650 +/- 0.113806

# %% [markdown]
# The mean squared errors are relatively high and dispersed. The orientations of fiber bundles (red lines) and volumes of intra-cellular diffusion (grayscale shades) look random on a visualization below.

# %%
def visualize_result(bas_models_fit):

    affine = np.eye(4)
    affine[0,3] = -10
    affine[1,3] = -10

    volume = np.zeros([roi['width'], roi['height'], 1])
    peak_dirs = np.zeros([roi['width'], roi['height'], 1, 1, 3])

    for x in range(roi['width']):
        for y in range(roi['height']):
            volume[x, y, 0] = bas_models_fit[x][y].fitted_parameters['partial_volume_0']
            peak_cart = np.squeeze(bas_models_fit[x][y].peaks_cartesian())
            peak_dirs[x, y, 0] = [peak_cart[0], peak_cart[2], -peak_cart[1]]

    ren = window.ren()
    ren.add(actor.slicer(volume, interpolation='nearest', affine=affine, opacity=0.7))
    ren.add(actor.peak_slicer(peak_dirs, None, affine=affine, linewidth=5, colors=None))   

    window.record(ren, size=[700, 700], out_path='dipy.png')
    
    img = mpimg.imread('dipy.png')
    plt.figure(figsize=[10, 10])
    plt.imshow(img) #[100:-97, 100:-85])
    plt.axis('off');
    
print("our randomized model:")
visualize_result(our_bas_model)
# Out:
# our randomized model:

# %% [markdown]
# ### State-of-the-art solution
#
# For comparison, let's try now a state-of-the-art solution.

# %%
# %%time
reference_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    reference_bas_model[x] = {}
    for y in range(roi['height']):
        
        voxel_signal = data_hcp_roi[x, 0, y, :]
        reference_bas_model[x][y] = bas_model.fit(scheme_hcp, voxel_signal)
        
        voxel_mse[x][y] = reference_bas_model[x][y].mean_squared_error(voxel_signal)
        
print("Fitting accuracy:")        
print("MSE +/- STD = %f +/- %f" % (np.mean(voxel_mse), np.std(voxel_mse)))
# Out:
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.3140828609466553 seconds
# Fitting of 1 voxels complete in 2.898350715637207 seconds.
# Average of 2.898350715637207 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.29415416717529297 seconds
# Fitting of 1 voxels complete in 2.2313249111175537 seconds.
# Average of 2.2313249111175537 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27869367599487305 seconds
# Fitting of 1 voxels complete in 2.177934169769287 seconds.
# Average of 2.177934169769287 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.277789831161499 seconds
# Fitting of 1 voxels complete in 2.1657423973083496 seconds.
# Average of 2.1657423973083496 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2782931327819824 seconds
# Fitting of 1 voxels complete in 2.1238839626312256 seconds.
# Average of 2.1238839626312256 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28516530990600586 seconds
# Fitting of 1 voxels complete in 2.1491305828094482 seconds.
# Average of 2.1491305828094482 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27628636360168457 seconds
# Fitting of 1 voxels complete in 2.1845200061798096 seconds.
# Average of 2.1845200061798096 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28094053268432617 seconds
# Fitting of 1 voxels complete in 2.178687810897827 seconds.
# Average of 2.178687810897827 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2833278179168701 seconds
# Fitting of 1 voxels complete in 2.1827504634857178 seconds.
# Average of 2.1827504634857178 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28427743911743164 seconds
# Fitting of 1 voxels complete in 2.175896406173706 seconds.
# Average of 2.175896406173706 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2763094902038574 seconds
# Fitting of 1 voxels complete in 2.146972179412842 seconds.
# Average of 2.146972179412842 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28777337074279785 seconds
# Fitting of 1 voxels complete in 2.129664897918701 seconds.
# Average of 2.129664897918701 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.29025936126708984 seconds
# Fitting of 1 voxels complete in 2.263073444366455 seconds.
# Average of 2.263073444366455 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.3010876178741455 seconds
# Fitting of 1 voxels complete in 2.1751532554626465 seconds.
# Average of 2.1751532554626465 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2844219207763672 seconds
# Fitting of 1 voxels complete in 2.1444742679595947 seconds.
# Average of 2.1444742679595947 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27295565605163574 seconds
# Fitting of 1 voxels complete in 2.1721205711364746 seconds.
# Average of 2.1721205711364746 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.
seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27526426315307617 seconds
# Fitting of 1 voxels complete in 2.1377570629119873 seconds.
# Average of 2.1377570629119873 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.26931118965148926 seconds
# Fitting of 1 voxels complete in 2.1096363067626953 seconds.
# Average of 2.1096363067626953 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2822449207305908 seconds
# Fitting of 1 voxels complete in 2.113131046295166 seconds.
# Average of 2.113131046295166 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.26832127571105957 seconds
# Fitting of 1 voxels complete in 2.1311471462249756 seconds.
# Average of 2.1311471462249756 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27630138397216797 seconds
# Fitting of 1 voxels complete in 2.1501412391662598 seconds.
# Average of 2.1501412391662598 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2723104953765869 seconds
# Fitting of 1 voxels complete in 2.1029796600341797 seconds.
# Average of 2.1029796600341797 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27131152153015137 seconds
# Fitting of 1 voxels complete in 2.1080806255340576 seconds.
# Average of 2.1080806255340576 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2743039131164551 seconds
# Fitting of 1 voxels complete in 2.1665031909942627 seconds.
# Average of 2.1665031909942627 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.27619218826293945 seconds
# Fitting of 1 voxels complete in 2.166635036468506 seconds.
# Average of 2.166635036468506 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.276292085647583 seconds
# Fitting of 1 voxels complete in 2.0705697536468506 seconds.
# Average of 2.0705697536468506 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.2723104953765869 seconds
# Fitting of 1 voxels complete in 2.2340071201324463 seconds.
# Average of 2.2340071201324463 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.31615495681762695 seconds
# Fitting of 1 voxels complete in 2.4831416606903076 seconds.
# Average of 2.4831416606903076 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28426504135131836 seconds
# Fitting of 1 voxels complete in 2.2086172103881836 seconds.
# Average of 2.2086172103881836 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28127336502075195 seconds
# Fitting of 1 voxels complete in 2.1159043312072754 seconds.
# Average of 2.1159043312072754 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.28028154373168945 seconds
# Fitting of 1 voxels complete in 2.265259027481079 seconds.
# Average of 2.265259027481079 seconds per voxel.
# Using parallel processing with 8 workers.
# Setup brute2fine optimizer in 0.29224252700805664 seconds
# Fitting of 1 voxels complete in 2.309717893600464 seconds.
# Average of 2.309717893600464 seconds per voxel.
# Fitting accuracy:
# MSE +/- STD = 0.003143 +/- 0.001678
# Wall time: 16min 27s

# %% [markdown]
# The MSEs and STDs are much lower than before. Also, the visualization of fiber bundles looks more realistic.

# %%
print("state-of-the-art model:")
visualize_result(reference_bas_model)
# Out:
# state-of-the-art model:

# %% [markdown]
# ### Assignment
#
# Use any optimization engine that you know (e.g. genetic algorithm) and compare your results with the state-of-the-art solution.
# - Can your solution produce more exact fitting?
# - Are the MSEs less dispersed?
# - Does it work faster than the reference method?

# %% [markdown]
# ## PLAN
# - ES gdzie jeśli poza dziedziną to losujemy z dziedziny

# %%
def domain_dict_to_array(d):
    domains_dict = d
    domains_list = np.array(list(domains_dict.values()))
    domains_array = np.array(domains_list[0][0])
    domains_array = np.vstack((domains_array, domains_list[0][1]))
    domains_array = np.vstack((domains_array, domains_list[1]))
    domains_array = np.vstack((domains_array, domains_list[2]))
    domains_array = np.vstack((domains_array, domains_list[3]))
    domains_array = np.vstack((domains_array, domains_list[4]))
    return domains_array

# %%
bas_model.parameter_ranges
# Out:
# OrderedDict([('C1Stick_1_mu',
#               ([0, 3.141592653589793],
#                [-3.141592653589793, 3.141592653589793])),
#              ('C1Stick_1_lambda_par', (0.1, 3)),
#              ('G1Ball_1_lambda_iso', (0.1, 3)),
#              ('partial_volume_0', (0.01, 0.99)),
#              ('partial_volume_1', (0.01, 0.99))])

# %%
domain_dict_to_array(bas_model.parameter_ranges)
# Out:
# array([[0.0, 3.141592653589793],
#        [-3.141592653589793, 3.141592653589793],
#        [0.1, 3],
#        [0.1, 3],
#        [0.01, 0.99],
#        [0.01, 0.99]], dtype=object)

# %%
# 6 values per voxel so x * y * 6 in chromosome

# %%
x_me, y_me = 20, 20
chromosome_example = np.zeros((x_me, y_me, 6))
print(chromosome_example.shape)
# Out:
# (20, 20, 6)

# %%
def array_to_dict(a):
    # TODO
    # do poprawy bo C1Stick_1_mu ma tupla a nie jedną wartość
    d = bas_model.parameter_ranges
    fd = {}
    fd['C1Stick_1_mu'] = a[0]
    fd['C1Stick_1_lambda_par'] = a[1]
    fd['G1Ball_1_lambda_iso'] = a[1]
    fd['partial_volume_0'] = a[1]
    fd['partial_volume_1'] = a[1]
    return fd

# %%
chro1 = chromosome_example[0][0]
array_to_dict(chro1)
# Out:
# {'C1Stick_1_mu': 0.0,
#  'C1Stick_1_lambda_par': 0.0,
#  'G1Ball_1_lambda_iso': 0.0,
#  'partial_volume_0': 0.0,
#  'partial_volume_1': 0.0}

# %%
domain_dict_to_array(bas_model.parameter_ranges)
# Out:
# array([[0.0, 3.141592653589793],
#        [-3.141592653589793, 3.141592653589793],
#        [0.1, 3],
#        [0.1, 3],
#        [0.01, 0.99],
#        [0.01, 0.99]], dtype=object)

# %%
def es(objective_function, chromosome_length, population_size, number_of_iterations, number_of_offspring, number_of_parents, sigma, tau, tau_0, log_frequency=1, R=None):

    best_solution = np.empty((1, chromosome_length))
    best_solution_objective_value = 1e10

    log_objective_values = np.empty((number_of_iterations, 4))
    log_best_solutions = np.empty((number_of_iterations, chromosome_length))
    
    def mut3(og):
        S = np.random.uniform(0,sigma, size=(chromosome_length, chromosome_length))
        S = np.dot(S,S.T)
        return og + np.dot(np.random.randn(number_of_offspring, chromosome_length), np.linalg.cholesky(S).T)
    
    def in_domain(chrom, R):
        for p in range(len(chrom)):
            R_ind = p % 6
            if not R[R_ind][0] < chrom[p] < R[R_ind][1]:
                chrom[p] = np.random.uniform(R[R_ind][0],R[R_ind][1])
        return chrom
    
    def initial_population(population_size, R):
        current_population_solutions = np.zeros((population_size, chromosome_length))
        for pop in range(population_size):
            for p in range(chromosome_length):
                R_ind = p % 6
                current_population_solutions[pop][p] = np.random.uniform(R[R_ind][0],R[R_ind][1])
        return current_population_solutions
            
    
    mutation_f = mut3

    # generating an initial population
    current_population_solutions = initial_population(population_size, R)

    # evaluating the objective function on the current population
    current_population_objective_values = np.zeros(population_size)
    for i, guy in enumerate(current_population_solutions):
            current_population_objective_values[i] = objective_function(guy)

    for t in tqdm.tqdm(range(number_of_iterations)):

        # selecting the parent indices by the roulette wheel method
        fitness_values = current_population_objective_values - current_population_objective_values.min()
        if fitness_values.sum() > 0:
            fitness_values = fitness_values / fitness_values.sum()
        else:
            fitness_values = 1.0 / population_size * np.ones(population_size)
        parent_indices = np.random.choice(population_size, (number_of_offspring, number_of_parents), True, fitness_values).astype(np.int64)

        # creating the children population by Global Intermediere Recombination
        children_population_solutions = np.zeros((number_of_offspring, chromosome_length))
        
        for i in range(number_of_offspring):
            children_population_solutions[i, :] = current_population_solutions[parent_indices[i, :], :].mean(axis=0)

        # mutating the children population by adding random gaussian noise
        children_population_solutions = mutation_f(children_population_solutions)
        
        # check if in domain
        for chrom in children_population_solutions:
            chrom = in_domain(chrom, R)                
        
        # evaluating the objective function on the children population
        children_population_objective_values = np.zeros(len(children_population_solutions))
        for i, child in enumerate(children_population_solutions):
            children_population_objective_values[i] = objective_function(child)

        # replacing the current population by (Mu + Lambda) Replacement
        current_population_objective_values = np.hstack([current_population_objective_values, children_population_objective_values])
        current_population_solutions = np.vstack([current_population_solutions, children_population_solutions])

        I = np.argsort(-current_population_objective_values)[::-1]
        current_population_solutions = current_population_solutions[I[:population_size], :]
        current_population_objective_values = current_population_objective_values[I[:population_size]]

        # recording some statistics
        if best_solution_objective_value > current_population_objective_values[0]:
            best_solution = current_population_solutions[0]
            best_solution_objective_value = current_population_objective_values[0]
        log_objective_values[t, :] = [current_population_objective_values.min(), current_population_objective_values.max(), current_population_objective_values.mean(), current_population_objective_values.std()]
        log_best_solutions[t, :] = current_population_solutions[0, :]
        
        if log_frequency != -1 and np.mod(t, log_frequency) == 0:
            print("Iteration %04d : best score = %0.8f, mean score = %0.8f." % (t, log_objective_values[:t+1, 0].min(), log_objective_values[t, 2]))
    return best_solution_objective_value, best_solution, log_objective_values, log_best_solutions

# %%
def plot_values(history_objective_values): 
    plt.figure(figsize=(18, 4))
    plt.plot(history_objective_values[:, 0], 'g-',label='min')
    plt.plot(history_objective_values[:, 1], 'r-',label='max')
    plt.plot(history_objective_values[:, 2], 'b-',label='avg')
    plt.legend()
    plt.xlabel('iteration')
    plt.ylabel('objective function value')
    plt.title('min/avg/max objective function values')
    plt.show()

# %%
def set_random_parameters(our_voxel_bas_model, scheme_hcp, voxel_signal):
    params = []

    # estimate S0
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    # G1Ball_1_lambda_iso
    param_range = our_voxel_bas_model.parameter_ranges['G1Ball_1_lambda_iso']
    lambda_iso = np.random.uniform(param_range[0], param_range[1]) * 1e-09

    # C1Stick_1_mu
    param_ranges = our_voxel_bas_model.parameter_ranges['C1Stick_1_mu']
    mu_1 = np.random.uniform(param_ranges[0][0], param_ranges[0][1])
    mu_2 = np.random.uniform(param_ranges[1][0], param_ranges[1][1])
    
    # C1Stick_1_lambda_par
    param_range = our_voxel_bas_model.parameter_ranges['C1Stick_1_lambda_par']
    lambda_parallel = np.random.uniform(param_range[0], param_range[1]) * 1e-09
    
    # partial_volume_0
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_0']
    f_stick = np.random.uniform(param_range[0], param_range[1])
    
    # partial_volume_1
    param_range = our_voxel_bas_model.parameter_ranges['partial_volume_1']
    f_ball = np.random.uniform(param_range[0], param_range[1])
            
    return FittedMultiCompartmentModel(
        our_voxel_bas_model, np.array(S0), np.array([True]), 
        np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )


def set_params_from_chrom(chrom, our_voxel_bas_model, scheme_hcp, voxel_signal):
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    mu_1, mu_2 = chrom[0], chrom[1]
    lambda_parallel = chrom[2] * 1e-09
    lambda_iso = chrom[3] * 1e-09
    f_stick = chrom[4]
    f_ball = chrom[5]
    
    return FittedMultiCompartmentModel(
            our_voxel_bas_model, np.array(S0), np.array([True]), 
            np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )

def objective_function(ch, bas_model, scheme_hcp, voxel_signal):
    new_chroms = ch.reshape((roi['width'], roi['height'], 6))
    
    our_bas_model = {}
    voxel_mse = np.zeros([roi['width'], roi['height']])

    for x in range(roi['width']):
        our_bas_model[x] = {}
        for y in range(roi['height']):

            voxel_signal = data_hcp_roi[x, 0, y, :]
            our_bas_model[x][y] = set_params_from_chrom(new_chroms[x][y], bas_model, scheme_hcp, voxel_signal)

            voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

    return np.mean(voxel_mse)

# %%
d = 6 * 20 * 20
N = 200
T = 30

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome = es(
    lambda ch: objective_function(ch, bas_model, scheme_hcp, voxel_signal), d, N, T, 2*N, 2, 5.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 5, R=domain_dict_to_array(bas_model.parameter_ranges))

plot_values(history_objective_values)
# Out:
#   3%|██▊                                                                                | 1/30 [00:23<11:31, 23.86s/it]
# Iteration 0000 : best score = 0.08847489, mean score = 0.09917853.
# 0.08847489207101812
#  20%|████████████████▌                                                                  | 6/30 [02:21<09:22, 23.44s/it]
# Iteration 0005 : best score = 0.08847489, mean score = 0.09549676.
# 0.08847489207101812
#  37%|██████████████████████████████                                                    | 11/30 [04:16<07:21, 23.21s/it]
# Iteration 0010 : best score = 0.08693082, mean score = 0.09430349.
# 0.08693081912056977
#  53%|███████████████████████████████████████████▋                                      | 16/30 [06:14<05:28, 23.45s/it]
# Iteration 0015 : best score = 0.08693082, mean score = 0.09342002.
# 0.08693081912056977
#  70%|█████████████████████████████████████████████████████████▍                        | 21/30 [08:14<03:36, 24.05s/it]
# Iteration 0020 : best score = 0.08693082, mean score = 0.09311343.
# 0.08693081912056977
#  87%|███████████████████████████████████████████████████████████████████████           | 26/30 [10:12<01:34, 23.64s/it]
# Iteration 0025 : best score = 0.08693082, mean score = 0.09272443.
# 0.08693081912056977
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [11:46<00:00, 23.55s/it]

# %%
d = 6 * 20 * 20
N = 100
T = 100

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

best_objective_value, best_chromosome, history_objective_values, history_best_chromosome = es(
    lambda ch: objective_function(ch, bas_model, scheme_hcp, voxel_signal), d, N, T, 2*N, 2, 5.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)), 5, R=domain_dict_to_array(bas_model.parameter_ranges))

plot_values(history_objective_values)
# Out:
#   1%|▊                                                                                 | 1/100 [00:12<20:05, 12.18s/it]
# Iteration 0000 : best score = 0.08922344, mean score = 0.09922103.
# 0.08922344368479013
#   6%|████▉                                                                             | 6/100 [01:14<19:12, 12.27s/it]
# Iteration 0005 : best score = 0.08782410, mean score = 0.09500234.
# 0.08782409984433656
#  11%|████████▉                                                                        | 11/100 [02:16<18:35, 12.54s/it]
# Iteration 0010 : best score = 0.08782410, mean score = 0.09396779.
# 0.08782409984433656
#  16%|████████████▉                                                                    | 16/100 [03:18<17:16, 12.34s/it]
# Iteration 0015 : best score = 0.08782410, mean score = 0.09353208.
# 0.08782409984433656
#  21%|█████████████████                                                                | 21/100 [04:18<15:58, 12.13s/it]
# Iteration 0020 : best score = 0.08782410, mean score = 0.09300748.
# 0.08782409984433656
#  26%|█████████████████████                                                            | 26/100 [05:18<14:48, 12.01s/it]
# Iteration 0025 : best score = 0.08782410, mean score = 0.09267169.
# 0.08782409984433656
#  31%|█████████████████████████                                                        | 31/100 [06:19<13:55, 12.11s/it]
# Iteration 0030 : best score = 0.08782410, mean score = 0.09212589.
# 0.08782409984433656
#  36%|█████████████████████████████▏                                                   | 36/100 [07:18<12:41, 11.90s/it]
# Iteration 0035 : best score = 0.08782410, mean score = 0.09190357.
# 0.08782409984433656
#  41%|█████████████████████████████████▏                                               | 41/100 [08:19<11:48, 12.00s/it]
# Iteration 0040 : best score = 0.08774228, mean score = 0.09159601.
# 0.0877422784779257
#  46%|█████████████████████████████████████▎                                           | 46/100 [09:18<10:49, 12.03s/it]
# Iteration 0045 : best score = 0.08774228, mean score = 0.09142785.
# 0.0877422784779257
#  51%|█████████████████████████████████████████▎                                       | 51/100 [10:20<09:51, 12.06s/it]
# Iteration 0050 : best score = 0.08774228, mean score = 0.09133533.
# 0.0877422784779257
#  56%|█████████████████████████████████████████████▎                                   | 56/100 [11:19<08:45, 11.95s/it]
# Iteration 0055 : best score = 0.08774228, mean score = 0.09121730.
# 0.0877422784779257
#  61%|█████████████████████████████████████████████████▍                               | 61/100 [12:18<07:38, 11.76s/it]
# Iteration 0060 : best score = 0.08774228, mean score = 0.09113558.
# 0.0877422784779257
#  66%|█████████████████████████████████████████████████████▍                           | 66/100 [13:16<06:36, 11.68s/it]
# Iteration 0065 : best score = 0.08774228, mean score = 0.09106498.
# 0.0877422784779257
#  71%|█████████████████████████████████████████████████████████▌                       | 71/100 [14:15<05:40, 11.74s/it]
# Iteration 0070 : best score = 0.08774228, mean score = 0.09101774.
# 0.0877422784779257
#  76%|█████████████████████████████████████████████████████████████▌                   | 76/100 [15:13<04:40, 11.68s/it]
# Iteration 0075 : best score = 0.08774228, mean score = 0.09094123.
# 0.0877422784779257
#  81%|█████████████████████████████████████████████████████████████████▌               | 81/100 [16:12<03:41, 11.65s/it]
# Iteration 0080 : best score = 0.08774228, mean score = 0.09089479.
# 0.0877422784779257
#  86%|█████████████████████████████████████████████████████████████████████▋           | 86/100 [17:11<02:44, 11.75s/it]
# Iteration 0085 : best score = 0.08774228, mean score = 0.09082207.
# 0.0877422784779257
#  91%|█████████████████████████████████████████████████████████████████████████▋       | 91/100 [18:09<01:45, 11.71s/it]
# Iteration 0090 : best score = 0.08774228, mean score = 0.09079353.
# 0.0877422784779257
#  96%|█████████████████████████████████████████████████████████████████████████████▊   | 96/100 [19:07<00:46, 11.63s/it]
# Iteration 0095 : best score = 0.08774228, mean score = 0.09077811.
# 0.0877422784779257
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [19:53<00:00, 11.93s/it]

# %%
def objective_function_and_model(ch, bas_model, scheme_hcp, voxel_signal):
    new_chroms = ch.reshape((roi['width'], roi['height'], 6))
    
    our_bas_model = {}
    voxel_mse = np.zeros([roi['width'], roi['height']])

    for x in range(roi['width']):
        our_bas_model[x] = {}
        for y in range(roi['height']):

            voxel_signal = data_hcp_roi[x, 0, y, :]
            our_bas_model[x][y] = set_params_from_chrom(new_chroms[x][y], bas_model, scheme_hcp, voxel_signal)

            voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

    return np.mean(voxel_mse), our_bas_model

# %%
best_mean, best_model = objective_function_and_model(best_chromosome,bas_model, scheme_hcp, voxel_signal)
visualize_result(best_model)

# %% [markdown]
# ## KROK 2
# spróbować dla każdego pixela znajdować optimum oddzielnie, na początek też ESem

# %%
def es_for_single_voxel(objective_function, chromosome_length, population_size, number_of_iterations, number_of_offspring, number_of_parents, sigma, tau, tau_0, log_frequency=1, R=None):

    best_solution = np.empty((1, chromosome_length))
    best_solution_objective_value = 1e10

    log_objective_values = np.empty((number_of_iterations, 4))
    log_best_solutions = np.empty((number_of_iterations, chromosome_length))
    
    def mut3(og):
        S = np.random.uniform(0,sigma, size=(chromosome_length, chromosome_length))
        S = np.dot(S,S.T)
        return og + np.dot(np.random.randn(number_of_offspring, chromosome_length), np.linalg.cholesky(S).T)
    
    def in_domain(chrom, R):
        for p in range(len(chrom)):
            if not R[p][0] < chrom[p] < R[p][1]:
                chrom[p] = np.random.uniform(R[p][0],R[p][1])
        return chrom
    
    def initial_population(population_size, R):
        current_population_solutions = np.zeros((population_size, chromosome_length))
        for pop in range(population_size):
            for p in range(chromosome_length):
                current_population_solutions[pop][p] = np.random.uniform(R[p][0],R[p][1])
        return current_population_solutions
            
    
    mutation_f = mut3

    # generating an initial population
    current_population_solutions = initial_population(population_size, R)

    # evaluating the objective function on the current population
    current_population_objective_values = np.zeros(population_size)
    for i, guy in enumerate(current_population_solutions):
            current_population_objective_values[i] = objective_function(guy)

    for t in range(number_of_iterations):

        # selecting the parent indices by the roulette wheel method
        fitness_values = current_population_objective_values - current_population_objective_values.min()
        if fitness_values.sum() > 0:
            fitness_values = fitness_values / fitness_values.sum()
        else:
            fitness_values = 1.0 / population_size * np.ones(population_size)
        parent_indices = np.random.choice(population_size, (number_of_offspring, number_of_parents), True, fitness_values).astype(np.int64)

        # creating the children population by Global Intermediere Recombination
        children_population_solutions = np.zeros((number_of_offspring, chromosome_length))
        
        for i in range(number_of_offspring):
            children_population_solutions[i, :] = current_population_solutions[parent_indices[i, :], :].mean(axis=0)

        # mutating the children population by adding random gaussian noise
        children_population_solutions = mutation_f(children_population_solutions)
        
        # check if in domain
        for chrom in children_population_solutions:
            chrom = in_domain(chrom, R)                
        
        # evaluating the objective function on the children population
        children_population_objective_values = np.zeros(len(children_population_solutions))
        for i, child in enumerate(children_population_solutions):
            children_population_objective_values[i] = objective_function(child)

        # replacing the current population by (Mu + Lambda) Replacement
        current_population_objective_values = np.hstack([current_population_objective_values, children_population_objective_values])
        current_population_solutions = np.vstack([current_population_solutions, children_population_solutions])

        I = np.argsort(-current_population_objective_values)[::-1]
        current_population_solutions = current_population_solutions[I[:population_size], :]
        current_population_objective_values = current_population_objective_values[I[:population_size]]

        # recording some statistics
        if best_solution_objective_value > current_population_objective_values[0]:
            best_solution = current_population_solutions[0]
            best_solution_objective_value = current_population_objective_values[0]
        log_objective_values[t, :] = [current_population_objective_values.min(), current_population_objective_values.max(), current_population_objective_values.mean(), current_population_objective_values.std()]
        log_best_solutions[t, :] = current_population_solutions[0, :]
        
        if log_frequency != -1 and np.mod(t, log_frequency) == 0:
            print("Iteration %04d : best score = %0.8f, mean score = %0.8f." % (t, log_objective_values[:t+1, 0].min(), log_objective_values[t, 2]))
    return best_solution_objective_value, best_solution, log_objective_values, log_best_solutions

# %%
def set_params_from_chrom(chrom, our_voxel_bas_model, scheme_hcp, voxel_signal):
    our_voxel_bas_model.scheme = scheme_hcp
    S0 = np.mean(voxel_signal[scheme_hcp.b0_mask], axis=-1)
    
    mu_1, mu_2 = chrom[0], chrom[1]
    lambda_parallel = chrom[2] * 1e-09
    lambda_iso = chrom[3] * 1e-09
    f_stick = chrom[4]
    f_ball = chrom[5]
    
    return FittedMultiCompartmentModel(
            our_voxel_bas_model, np.array(S0), np.array([True]), 
            np.array([[mu_1, mu_2, lambda_iso, lambda_parallel, f_stick, f_ball]])
    )


def single_voxel_function(chromosome, bas_model, scheme_hcp, voxel_signal):
    '''
    dla danego chromosomu o dl. 6 wypluwa jego MSE
    '''
    model = set_params_from_chrom(chromosome, bas_model, scheme_hcp, voxel_signal)
    return model.mean_squared_error(voxel_signal)



# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 100

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 5.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
        print(f'Best MSE of voxel x={x},y={y} is {best_value}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)}')
# Out:
# Best MSE of voxel x=0,y=0 is 0.003367493960826681
# Best MSE of voxel x=0,y=1 is 0.005732832250355559
# Best MSE of voxel x=0,y=2 is 0.008755862342217856
# Best MSE of voxel x=0,y=3 is 0.008442467768133824
# Best MSE of voxel x=0,y=4 is 0.0037896691588865366
# Best MSE of voxel x=0,y=5 is 0.002691538185051079
# Best MSE of voxel x=0,y=6 is 0.004629858719002303
# Best MSE of voxel x=0,y=7 is 0.0049659922862578575
# Best MSE of voxel x=0,y=8 is 0.003066717337725047
# Best MSE of voxel x=0,y=9 is 0.00243622587501039
# Best MSE of voxel x=0,y=10 is 0.0035545375755367836
# Best MSE of voxel x=0,y=11 is 0.003090692160761017
# Best MSE of voxel x=0,y=12 is 0.0022842156601003477
# Best MSE of voxel x=0,y=13 is 0.0025379925608491993
# Best MSE of voxel x=0,y=14 is 0.002150801090147688
# Best MSE of voxel x=0,y=15 is 0.0016978339689374148
# Best MSE of voxel x=0,y=16 is 0.0008349665189790192
# Best MSE of voxel x=0,y=17 is 0.00111366326646353
# Best MSE of voxel x=0,y=18 is 0.0019299138901567915
# Best MSE of voxel x=0,y=19 is 0.002782115373212779
# Best MSE of voxel x=1,y=0 is 0.0033920875117864607
# Best MSE of voxel x=1,y=1 is 0.004430203556197165
# Best MSE of voxel x=1,y=2 is 0.00734115102803232
# Best MSE of voxel x=1,y=3 is 0.005940544548085664
# Best MSE of voxel x=1,y=4 is 0.0024133731056418203
# Best MSE of voxel x=1,y=5 is 0.0012660407675002148
# Best MSE of voxel x=1,y=6 is 0.0026159453657856307
# Best MSE of voxel x=1,y=7 is 0.0026072144863682626
# Best MSE of voxel x=1,y=8 is 0.0021371622657733263
# Best MSE of voxel x=1,y=9 is 0.0032460705108544132
# Best MSE of voxel x=1,y=10 is 0.0043174737076160825
# Best MSE of voxel x=1,y=11 is 0.0027359184174868267
# Best MSE of voxel x=1,y=12 is 0.0020711822933001164
# Best MSE of voxel x=1,y=13 is 0.0018374226410242474
# Best MSE of voxel x=1,y=14 is 0.0020317881820668595
# Best MSE of voxel x=1,y=15 is 0.001529700800124482
# Best MSE of voxel x=1,y=16 is 0.0010565018827054947
# Best MSE of voxel x=1,y=17 is 0.0006122376884325949
# Best MSE of voxel x=1,y=18 is 0.0006745802071977699
# Best MSE of voxel x=1,y=19 is 0.0015569630848462183
# Best MSE of voxel x=2,y=0 is 0.0033439774723162644
# Best MSE of voxel x=2,y=1 is 0.006415981459005454
# Best MSE of voxel x=2,y=2 is 0.007110410154613682
# Best MSE of voxel x=2,y=3 is 0.007721801750180747
# Best MSE of voxel x=2,y=4 is 0.0033698594229775087
# Best MSE of voxel x=2,y=5 is 0.0010922002838889883
# Best MSE of voxel x=2,y=6 is 0.0013066581675327707
# Best MSE of voxel x=2,y=7 is 0.0022562775830259974
# Best MSE of voxel x=2,y=8 is 0.0016724967338039988
# Best MSE of voxel x=2,y=9 is 0.0035825837951358372
# Best MSE of voxel x=2,y=10 is 0.0059004605217161995
# Best MSE of voxel x=2,y=11 is 0.0031402341031373355
# Best MSE of voxel x=2,y=12 is 0.0018795872681092035
# Best MSE of voxel x=2,y=13 is 0.0015875572812998721
# Best MSE of voxel x=2,y=14 is 0.0016660517244631585
# Best MSE of voxel x=2,y=15 is 0.0011292511531372411
# Best MSE of voxel x=2,y=16 is 0.0015306880190143455
# Best MSE of voxel x=2,y=17 is 0.0013139944977994887
# Best MSE of voxel x=2,y=18 is 0.0006385899711521052
# Best MSE of voxel x=2,y=19 is 0.0005011138167377503
# Best MSE of voxel x=3,y=0 is 0.0032336042533626284
# Best MSE of voxel x=3,y=1 is 0.005831128495513756
# Best MSE of voxel x=3,y=2 is 0.006067226709567598
# Best MSE of voxel x=3,y=3 is 0.007393565145490811
# Best MSE of voxel x=3,y=4 is 0.006357640151833059
# Best MSE of voxel x=3,y=5 is 0.0011540173367093698
# Best MSE of voxel x=3,y=6 is 0.0017099577323470368
# Best MSE of voxel x=3,y=7 is 0.0032542381088993366
# Best MSE of voxel x=3,y=8 is 0.00203631085801619
# Best MSE of voxel x=3,y=9 is 0.0021038380132167786
# Best MSE of voxel x=3,y=10 is 0.002404134270716925
# Best MSE of voxel x=3,y=11 is 0.0021325744030202404
# Best MSE of voxel x=3,y=12 is 0.0019942677113784757
# Best MSE of voxel x=3,y=13 is 0.00254338477827305
# Best MSE of voxel x=3,y=14 is 0.0020002412260957192
# Best MSE of voxel x=3,y=15 is 0.0018995704899838106
# Best MSE of voxel x=3,y=16 is 0.0017172465663046097
# Best MSE of voxel x=3,y=17 is 0.0016558456358953253
# Best MSE of voxel x=3,y=18 is 0.0008152128838265606
# Best MSE of voxel x=3,y=19 is 0.0011424720363846091
# Best MSE of voxel x=4,y=0 is 0.0013630732461062495
# Best MSE of voxel x=4,y=1 is 0.0035081472596106924
# Best MSE of voxel x=4,y=2 is 0.008527361315907136
# Best MSE of voxel x=4,y=3 is 0.00705824424462974
# Best MSE of voxel x=4,y=4 is 0.007421429289811054
# Best MSE of voxel x=4,y=5 is 0.003836242874586029
# Best MSE of voxel x=4,y=6 is 0.0033510039380030424
# Best MSE of voxel x=4,y=7 is 0.004514623943243348
# Best MSE of voxel x=4,y=8 is 0.003170058171579544
# Best MSE of voxel x=4,y=9 is 0.002982725275667501
# Best MSE of voxel x=4,y=10 is 0.0018235954556029119
# Best MSE of voxel x=4,y=11 is 0.0022894334224970595
# Best MSE of voxel x=4,y=12 is 0.0028832246745110323
# Best MSE of voxel x=4,y=13 is 0.0028104186700915706
# Best MSE of voxel x=4,y=14 is 0.0031757431324443038
# Best MSE of voxel x=4,y=15 is 0.00290224184525029
# Best MSE of voxel x=4,y=16 is 0.0018378176723960753
# Best MSE of voxel x=4,y=17 is 0.0016503446099106085
# Best MSE of voxel x=4,y=18 is 0.0013477225263334922
# Best MSE of voxel x=4,y=19 is 0.0021439233243243714
# Best MSE of voxel x=5,y=0 is 0.0006795015792703341
# Best MSE of voxel x=5,y=1 is 0.0021603346584132188
# Best MSE of voxel x=5,y=2 is 0.0059855763550047385
# Best MSE of voxel x=5,y=3 is 0.00942503742436226
# Best MSE of voxel x=5,y=4 is 0.005710370511583721
# Best MSE of voxel x=5,y=5 is 0.005632023567567552
# Best MSE of voxel x=5,y=6 is 0.004169056217544421
# Best MSE of voxel x=5,y=7 is 0.004841874901341001
# Best MSE of voxel x=5,y=8 is 0.005470348939235516
# Best MSE of voxel x=5,y=9 is 0.004543175937620519
# Best MSE of voxel x=5,y=10 is 0.0028564008502491777
# Best MSE of voxel x=5,y=11 is 0.004427924134284966
# Best MSE of voxel x=5,y=12 is 0.005940980218862867
# Best MSE of voxel x=5,y=13 is 0.005315601291613528
# Best MSE of voxel x=5,y=14 is 0.0032711300615188097
# Best MSE of voxel x=5,y=15 is 0.001856194691660406
# Best MSE of voxel x=5,y=16 is 0.0021469345680946413
# Best MSE of voxel x=5,y=17 is 0.0014078223171338441
# Best MSE of voxel x=5,y=18 is 0.002026830370227474
# Best MSE of voxel x=5,y=19 is 0.0037863144836770574
# Best MSE of voxel x=6,y=0 is 0.0008772239076947295
# Best MSE of voxel x=6,y=1 is 0.0010677648311656438
# Best MSE of voxel x=6,y=2 is 0.00311384599329749
# Best MSE of voxel x=6,y=3 is 0.009720474275700091
# Best MSE of voxel x=6,y=4 is 0.008384312610247361
# Best MSE of voxel x=6,y=5 is 0.009287297820261152
# Best MSE of voxel x=6,y=6 is 0.004137846191500521
# Best MSE of voxel x=6,y=7 is 0.006869267963418769
# Best MSE of voxel x=6,y=8 is 0.008503518024868833
# Best MSE of voxel x=6,y=9 is 0.005952752732548519
# Best MSE of voxel x=6,y=10 is 0.0037945174641098676
# Best MSE of voxel x=6,y=11 is 0.007569121907795692
# Best MSE of voxel x=6,y=12 is 0.008204290709344907
# Best MSE of voxel x=6,y=13 is 0.0034950088195193235
# Best MSE of voxel x=6,y=14 is 0.001785610767085524
# Best MSE of voxel x=6,y=15 is 0.0013994661060751827
# Best MSE of voxel x=6,y=16 is 0.0015216441480181528
# Best MSE of voxel x=6,y=17 is 0.002063318026649703
# Best MSE of voxel x=6,y=18 is 0.002564146406887534
# Best MSE of voxel x=6,y=19 is 0.004159242234125074
# Best MSE of voxel x=7,y=0 is 0.0006826491311057095
# Best MSE of voxel x=7,y=1 is 0.0010619656248823097
# Best MSE of voxel x=7,y=2 is 0.0012977354837412974
# Best MSE of voxel x=7,y=3 is 0.006393328778552167
# Best MSE of voxel x=7,y=4 is 0.007502590772676103
# Best MSE of voxel x=7,y=5 is 0.008518192266484679
# Best MSE of voxel x=7,y=6 is 0.006466433939378357
# Best MSE of voxel x=7,y=7 is 0.00767835773235033
# Best MSE of voxel x=7,y=8 is 0.0061695680883759475
# Best MSE of voxel x=7,y=9 is 0.0070903696903632
# Best MSE of voxel x=7,y=10 is 0.0055548806798827585
# Best MSE of voxel x=7,y=11 is 0.007749488343608946
# Best MSE of voxel x=7,y=12 is 0.0042221270683600225
# Best MSE of voxel x=7,y=13 is 0.002062910089898196
# Best MSE of voxel x=7,y=14 is 0.0014940765950842126
# Best MSE of voxel x=7,y=15 is 0.000894728725494206
# Best MSE of voxel x=7,y=16 is 0.001178117862390452
# Best MSE of voxel x=7,y=17 is 0.0024357921846613465
# Best MSE of voxel x=7,y=18 is 0.002331364509146482
# Best MSE of voxel x=7,y=19 is 0.0034203071978469377
# Best MSE of voxel x=8,y=0 is 0.0014320511139724918
# Best MSE of voxel x=8,y=1 is 0.0007050172064079275
# Best MSE of voxel x=8,y=2 is 0.0007750557906423559
# Best MSE of voxel x=8,y=3 is 0.0019457231149128465
# Best MSE of voxel x=8,y=4 is 0.010533450345532722
# Best MSE of voxel x=8,y=5 is 0.007842950857029173
# Best MSE of voxel x=8,y=6 is 0.007104123952642703
# Best MSE of voxel x=8,y=7 is 0.00770077899042767
# Best MSE of voxel x=8,y=8 is 0.007501740361720133
# Best MSE of voxel x=8,y=9 is 0.005198160702855184
# Best MSE of voxel x=8,y=10 is 0.008161244139074906
# Best MSE of voxel x=8,y=11 is 0.008787863173635533
# Best MSE of voxel x=8,y=12 is 0.002153044638950107
# Best MSE of voxel x=8,y=13 is 0.0018119510452128604
# Best MSE of voxel x=8,y=14 is 0.0008392605512586071
# Best MSE of voxel x=8,y=15 is 0.0010703152761860272
# Best MSE of voxel x=8,y=16 is 0.002309837543188961
# Best MSE of voxel x=8,y=17 is 0.0029096352063717706
# Best MSE of voxel x=8,y=18 is 0.0029008965887313645
# Best MSE of voxel x=8,y=19 is 0.003720441959720786
# Best MSE of voxel x=9,y=0 is 0.002593609908448
# Best MSE of voxel x=9,y=1 is 0.0005679087699085022
# Best MSE of voxel x=9,y=2 is 0.0005631371356353919
# Best MSE of voxel x=9,y=3 is 0.0010445015659977957
# Best MSE of voxel x=9,y=4 is 0.00566609245675362
# Best MSE of voxel x=9,y=5 is 0.008888119584581652
# Best MSE of voxel x=9,y=6 is 0.009196642512116299
# Best MSE of voxel x=9,y=7 is 0.007847414652193097
# Best MSE of voxel x=9,y=8 is 0.005375989641780567
# Best MSE of voxel x=9,y=9 is 0.006276552733552616
# Best MSE of voxel x=9,y=10 is 0.010200207927170647
# Best MSE of voxel x=9,y=11 is 0.005443259578804378
# Best MSE of voxel x=9,y=12 is 0.0019690839213034415
# Best MSE of voxel x=9,y=13 is 0.0015153765981278423
# Best MSE of voxel x=9,y=14 is 0.0009762958694399719
# Best MSE of voxel x=9,y=15 is 0.0028305851617682954
# Best MSE of voxel x=9,y=16 is 0.003040869672367233
# Best MSE of voxel x=9,y=17 is 0.00263529857245787
# Best MSE of voxel x=9,y=18 is 0.003184831226540558
# Best MSE of voxel x=9,y=19 is 0.004108055891400259
# Best MSE of voxel x=10,y=0 is 0.0022192763379157354
# Best MSE of voxel x=10,y=1 is 0.0007517347937264122
# Best MSE of voxel x=10,y=2 is 0.0007183714049548396
# Best MSE of voxel x=10,y=3 is 0.0008761486334932677
# Best MSE of voxel x=10,y=4 is 0.0020877806299103023
# Best MSE of voxel x=10,y=5 is 0.007121805242932624
# Best MSE of voxel x=10,y=6 is 0.008229659993167446
# Best MSE of voxel x=10,y=7 is 0.0049444942365093805
# Best MSE of voxel x=10,y=8 is 0.005664273702183486
# Best MSE of voxel x=10,y=9 is 0.005600582915064733
# Best MSE of voxel x=10,y=10 is 0.007815167548930652
# Best MSE of voxel x=10,y=11 is 0.005029272601792537
# Best MSE of voxel x=10,y=12 is 0.002158622875521002
# Best MSE of voxel x=10,y=13 is 0.0016636076069925971
# Best MSE of voxel x=10,y=14 is 0.0018143951146072622
# Best MSE of voxel x=10,y=15 is 0.0024054352517699604
# Best MSE of voxel x=10,y=16 is 0.0035533131335275647
# Best MSE of voxel x=10,y=17 is 0.0028338271614691954
# Best MSE of voxel x=10,y=18 is 0.004073740600834486
# Best MSE of voxel x=10,y=19 is 0.0043417532672644565
# Best MSE of voxel x=11,y=0 is 0.003880366084730819
# Best MSE of voxel x=11,y=1 is 0.0007009144029981538
# Best MSE of voxel x=11,y=2 is 0.0005601951811141643
# Best MSE of voxel x=11,y=3 is 0.000663544292764858
# Best MSE of voxel x=11,y=4 is 0.0009451302717128739
# Best MSE of voxel x=11,y=5 is 0.0031118515222524987
# Best MSE of voxel x=11,y=6 is 0.008744752773102825
# Best MSE of voxel x=11,y=7 is 0.006680095464728852
# Best MSE of voxel x=11,y=8 is 0.005431185601407273
# Best MSE of voxel x=11,y=9 is 0.006704451579760401
# Best MSE of voxel x=11,y=10 is 0.008074684492312006
# Best MSE of voxel x=11,y=11 is 0.004943433335691652
# Best MSE of voxel x=11,y=12 is 0.0027096750084710302
# Best MSE of voxel x=11,y=13 is 0.0015939743169504459
# Best MSE of voxel x=11,y=14 is 0.002033120979566199
# Best MSE of voxel x=11,y=15 is 0.0028608217402490838
# Best MSE of voxel x=11,y=16 is 0.0028405410884488457
# Best MSE of voxel x=11,y=17 is 0.003442349272931121
# Best MSE of voxel x=11,y=18 is 0.0062165381214382654
# Best MSE of voxel x=11,y=19 is 0.004560767993553902
# Best MSE of voxel x=12,y=0 is 0.008287733200757229
# Best MSE of voxel x=12,y=1 is 0.001902340013037728
# Best MSE of voxel x=12,y=2 is 0.0008846063272303176
# Best MSE of voxel x=12,y=3 is 0.0006847213442349671
# Best MSE of voxel x=12,y=4 is 0.0007006022173146336
# Best MSE of voxel x=12,y=5 is 0.0010755971367825308
# Best MSE of voxel x=12,y=6 is 0.00852161159621078
# Best MSE of voxel x=12,y=7 is 0.007050105722947713
# Best MSE of voxel x=12,y=8 is 0.005473645254641847
# Best MSE of voxel x=12,y=9 is 0.006452949462733083
# Best MSE of voxel x=12,y=10 is 0.006771896000857828
# Best MSE of voxel x=12,y=11 is 0.005648714433657573
# Best MSE of voxel x=12,y=12 is 0.003516705302032987
# Best MSE of voxel x=12,y=13 is 0.0024307357768702767
# Best MSE of voxel x=12,y=14 is 0.002971634810987127
# Best MSE of voxel x=12,y=15 is 0.003874903362940595
# Best MSE of voxel x=12,y=16 is 0.004968250440469382
# Best MSE of voxel x=12,y=17 is 0.005080126686505373
# Best MSE of voxel x=12,y=18 is 0.005280147768165249
# Best MSE of voxel x=12,y=19 is 0.005675503002789113
# Best MSE of voxel x=13,y=0 is 0.008495835612534416
# Best MSE of voxel x=13,y=1 is 0.0053703930484765
# Best MSE of voxel x=13,y=2 is 0.0021024795679272464
# Best MSE of voxel x=13,y=3 is 0.0010669269376733497
# Best MSE of voxel x=13,y=4 is 0.0007015575198030773
# Best MSE of voxel x=13,y=5 is 0.0007870937295843082
# Best MSE of voxel x=13,y=6 is 0.004710814577739964
# Best MSE of voxel x=13,y=7 is 0.006495341517416171
# Best MSE of voxel x=13,y=8 is 0.006159938942473199
# Best MSE of voxel x=13,y=9 is 0.005845458012403742
# Best MSE of voxel x=13,y=10 is 0.005675580819597787
# Best MSE of voxel x=13,y=11 is 0.006991358544508119
# Best MSE of voxel x=13,y=12 is 0.006157835939563631
# Best MSE of voxel x=13,y=13 is 0.005349344232605271
# Best MSE of voxel x=13,y=14 is 0.0059892870024407
# Best MSE of voxel x=13,y=15 is 0.0067083787964615695
# Best MSE of voxel x=13,y=16 is 0.007753033222811446
# Best MSE of voxel x=13,y=17 is 0.0063681933099523245
# Best MSE of voxel x=13,y=18 is 0.005068844319779816
# Best MSE of voxel x=13,y=19 is 0.0062999267260534725
# Best MSE of voxel x=14,y=0 is 0.007041109215518562
# Best MSE of voxel x=14,y=1 is 0.005650077404243958
# Best MSE of voxel x=14,y=2 is 0.003790152890091877
# Best MSE of voxel x=14,y=3 is 0.004012866228208369
# Best MSE of voxel x=14,y=4 is 0.0015370143176908608
# Best MSE of voxel x=14,y=5 is 0.0019399081857609305
# Best MSE of voxel x=14,y=6 is 0.003478822090747506
# Best MSE of voxel x=14,y=7 is 0.006341299770136959
# Best MSE of voxel x=14,y=8 is 0.005734031319492385
# Best MSE of voxel x=14,y=9 is 0.00541220158293831
# Best MSE of voxel x=14,y=10 is 0.005410629082202979
# Best MSE of voxel x=14,y=11 is 0.00509291367722295
# Best MSE of voxel x=14,y=12 is 0.006871286776857113
# Best MSE of voxel x=14,y=13 is 0.006064218203452509
# Best MSE of voxel x=14,y=14 is 0.00587450908834842
# Best MSE of voxel x=14,y=15 is 0.005962586790909681
# Best MSE of voxel x=14,y=16 is 0.006229603681876801
# Best MSE of voxel x=14,y=17 is 0.0049248989226885935
# Best MSE of voxel x=14,y=18 is 0.006220966228909005
# Best MSE of voxel x=14,y=19 is 0.005665104213666782
# Best MSE of voxel x=15,y=0 is 0.005879878793986891
# Best MSE of voxel x=15,y=1 is 0.005028921893225092
# Best MSE of voxel x=15,y=2 is 0.005790279371074993
# Best MSE of voxel x=15,y=3 is 0.005772376169737755
# Best MSE of voxel x=15,y=4 is 0.005059033824471699
# Best MSE of voxel x=15,y=5 is 0.004011198736354071
# Best MSE of voxel x=15,y=6 is 0.003632335592565943
# Best MSE of voxel x=15,y=7 is 0.006554105126996935
# Best MSE of voxel x=15,y=8 is 0.005857819049181633
# Best MSE of voxel x=15,y=9 is 0.005732942996399793
# Best MSE of voxel x=15,y=10 is 0.005664020779028904
# Best MSE of voxel x=15,y=11 is 0.004662679869737646
# Best MSE of voxel x=15,y=12 is 0.0037332066815448433
# Best MSE of voxel x=15,y=13 is 0.0035489890724402645
# Best MSE of voxel x=15,y=14 is 0.005228655913245558
# Best MSE of voxel x=15,y=15 is 0.004660232179942905
# Best MSE of voxel x=15,y=16 is 0.004651317190585039
# Best MSE of voxel x=15,y=17 is 0.005389706511856653
# Best MSE of voxel x=15,y=18 is 0.004858820263292104
# Best MSE of voxel x=15,y=19 is 0.005081102010445548
# Best MSE of voxel x=16,y=0 is 0.005911176363021635
# Best MSE of voxel x=16,y=1 is 0.004155212851879566
# Best MSE of voxel x=16,y=2 is 0.005753777671199525
# Best MSE of voxel x=16,y=3 is 0.006382042365725587
# Best MSE of voxel x=16,y=4 is 0.005443690917426265
# Best MSE of voxel x=16,y=5 is 0.005149256492927349
# Best MSE of voxel x=16,y=6 is 0.005556622640261751
# Best MSE of voxel x=16,y=7 is 0.005255011838893111
# Best MSE of voxel x=16,y=8 is 0.005654098277590899
# Best MSE of voxel x=16,y=9 is 0.0047835666584730525
# Best MSE of voxel x=16,y=10 is 0.005533583123749008
# Best MSE of voxel x=16,y=11 is 0.004202820761771097
# Best MSE of voxel x=16,y=12 is 0.003967376175715863
# Best MSE of voxel x=16,y=13 is 0.0042569670303038865
# Best MSE of voxel x=16,y=14 is 0.003511489162723929
# Best MSE of voxel x=16,y=15 is 0.0034764939253372393
# Best MSE of voxel x=16,y=16 is 0.00402528541580624
# Best MSE of voxel x=16,y=17 is 0.0037182653459070045
# Best MSE of voxel x=16,y=18 is 0.004710473656747341
# Best MSE of voxel x=16,y=19 is 0.004908793784117115
# Best MSE of voxel x=17,y=0 is 0.009212507337784788
# Best MSE of voxel x=17,y=1 is 0.0054536929829229995
# Best MSE of voxel x=17,y=2 is 0.0062219757539383165
# Best MSE of voxel x=17,y=3 is 0.004979163759157818
# Best MSE of voxel x=17,y=4 is 0.0060063295920073844
# Best MSE of voxel x=17,y=5 is 0.008333509960588657
# Best MSE of voxel x=17,y=6 is 0.005857653653437483
# Best MSE of voxel x=17,y=7 is 0.003968364051771461
# Best MSE of voxel x=17,y=8 is 0.004406190135927425
# Best MSE of voxel x=17,y=9 is 0.005171593680587452
# Best MSE of voxel x=17,y=10 is 0.005154342269036011
# Best MSE of voxel x=17,y=11 is 0.0039736047267221325
# Best MSE of voxel x=17,y=12 is 0.004721981204826104
# Best MSE of voxel x=17,y=13 is 0.004281726071105418
# Best MSE of voxel x=17,y=14 is 0.004852578079356902
# Best MSE of voxel x=17,y=15 is 0.00307423303975035
# Best MSE of voxel x=17,y=16 is 0.004502655406414158
# Best MSE of voxel x=17,y=17 is 0.004379595373357878
# Best MSE of voxel x=17,y=18 is 0.00436986802272912
# Best MSE of voxel x=17,y=19 is 0.004265579349854492
# Best MSE of voxel x=18,y=0 is 0.0073631497338777835
# Best MSE of voxel x=18,y=1 is 0.006083305593853128
# Best MSE of voxel x=18,y=2 is 0.005263390134686939
# Best MSE of voxel x=18,y=3 is 0.005142985173418552
# Best MSE of voxel x=18,y=4 is 0.0058095751808104985
# Best MSE of voxel x=18,y=5 is 0.007549587134577383
# Best MSE of voxel x=18,y=6 is 0.006554024590316516
# Best MSE of voxel x=18,y=7 is 0.004120252032336351
# Best MSE of voxel x=18,y=8 is 0.0036357137070862416
# Best MSE of voxel x=18,y=9 is 0.005014767588844557
# Best MSE of voxel x=18,y=10 is 0.004859711023645865
# Best MSE of voxel x=18,y=11 is 0.0038777979296309856
# Best MSE of voxel x=18,y=12 is 0.004240154326109148
# Best MSE of voxel x=18,y=13 is 0.003919809953424772
# Best MSE of voxel x=18,y=14 is 0.0038795554840573687
# Best MSE of voxel x=18,y=15 is 0.004708572464013796
# Best MSE of voxel x=18,y=16 is 0.0037645780572287727
# Best MSE of voxel x=18,y=17 is 0.004729587866933759
# Best MSE of voxel x=18,y=18 is 0.0031920748663726572
# Best MSE of voxel x=18,y=19 is 0.0033586164374872123
# Best MSE of voxel x=19,y=0 is 0.007117953557700356
# Best MSE of voxel x=19,y=1 is 0.0072005176029730856
# Best MSE of voxel x=19,y=2 is 0.008466882349315351
# Best MSE of voxel x=19,y=3 is 0.004986325128782502
# Best MSE of voxel x=19,y=4 is 0.005508638644283669
# Best MSE of voxel x=19,y=5 is 0.006028002167343457
# Best MSE of voxel x=19,y=6 is 0.006050473466469172
# Best MSE of voxel x=19,y=7 is 0.0046974620321695235
# Best MSE of voxel x=19,y=8 is 0.004303627606325716
# Best MSE of voxel x=19,y=9 is 0.005654384068702402
# Best MSE of voxel x=19,y=10 is 0.005422576802625142
# Best MSE of voxel x=19,y=11 is 0.0048101101055989404
# Best MSE of voxel x=19,y=12 is 0.005243857595452494
# Best MSE of voxel x=19,y=13 is 0.004713163554547773
# Best MSE of voxel x=19,y=14 is 0.0037456250328334172
# Best MSE of voxel x=19,y=15 is 0.0045533325936979105
# Best MSE of voxel x=19,y=16 is 0.004315703719778984
# Best MSE of voxel x=19,y=17 is 0.004710389333425503
# Best MSE of voxel x=19,y=18 is 0.0035040594358149205
# Best MSE of voxel x=19,y=19 is 0.003176524888115783
#
# Final MSE: 0.0042083816049771

# %%
# MAIN EVOLUTION PROCESS
d = 6
N = 10
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in range(roi['width']):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 5.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
        print(f'Best MSE of voxel x={x},y={y} is {np.round(best_value,4)}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
# Out:
# Best MSE of voxel x=0,y=0 is 0.0076
# Best MSE of voxel x=0,y=1 is 0.0138
# Best MSE of voxel x=0,y=2 is 0.0141
# Best MSE of voxel x=0,y=3 is 0.0089
# Best MSE of voxel x=0,y=4 is 0.0061
# Best MSE of voxel x=0,y=5 is 0.0045
# Best MSE of voxel x=0,y=6 is 0.0081
# Best MSE of voxel x=0,y=7 is 0.0067
# Best MSE of voxel x=0,y=8 is 0.0068
# Best MSE of voxel x=0,y=9 is 0.0039
# Best MSE of voxel x=0,y=10 is 0.0074
# Best MSE of voxel x=0,y=11 is 0.0069
# Best MSE of voxel x=0,y=12 is 0.0032
# Best MSE of voxel x=0,y=13 is 0.0035
# Best MSE of voxel x=0,y=14 is 0.0043
# Best MSE of voxel x=0,y=15 is 0.0018
# Best MSE of voxel x=0,y=16 is 0.005
# Best MSE of voxel x=0,y=17 is 0.0023
# Best MSE of voxel x=0,y=18 is 0.0035
# Best MSE of voxel x=0,y=19 is 0.0054
# Best MSE of voxel x=1,y=0 is 0.0085
# Best MSE of voxel x=1,y=1 is 0.0188
# Best MSE of voxel x=1,y=2 is 0.0132
# Best MSE of voxel x=1,y=3 is 0.0149
# Best MSE of voxel x=1,y=4 is 0.0066
# Best MSE of voxel x=1,y=5 is 0.0034
# Best MSE of voxel x=1,y=6 is 0.0037
# Best MSE of voxel x=1,y=7 is 0.006
# Best MSE of voxel x=1,y=8 is 0.006
# Best MSE of voxel x=1,y=9 is 0.0079
# Best MSE of voxel x=1,y=10 is 0.0076
# Best MSE of voxel x=1,y=11 is 0.0068
# Best MSE of voxel x=1,y=12 is 0.0028
# Best MSE of voxel x=1,y=13 is 0.008
# Best MSE of voxel x=1,y=14 is 0.003
# Best MSE of voxel x=1,y=15 is 0.0027
# Best MSE of voxel x=1,y=16 is 0.0036
# Best MSE of voxel x=1,y=17 is 0.0012
# Best MSE of voxel x=1,y=18 is 0.0026
# Best MSE of voxel x=1,y=19 is 0.0034
# Best MSE of voxel x=2,y=0 is 0.0063
# Best MSE of voxel x=2,y=1 is 0.0142
# Best MSE of voxel x=2,y=2 is 0.0183
# Best MSE of voxel x=2,y=3 is 0.0258
# Best MSE of voxel x=2,y=4 is 0.0115
# Best MSE of voxel x=2,y=5 is 0.0034
# Best MSE of voxel x=2,y=6 is 0.0025
# Best MSE of voxel x=2,y=7 is 0.0046
# Best MSE of voxel x=2,y=8 is 0.0033
# Best MSE of voxel x=2,y=9 is 0.0082
# Best MSE of voxel x=2,y=10 is 0.0104
# Best MSE of voxel x=2,y=11 is 0.0048
# Best MSE of voxel x=2,y=12 is 0.0035
# Best MSE of voxel x=2,y=13 is 0.0042
# Best MSE of voxel x=2,y=14 is 0.0041
# Best MSE of voxel x=2,y=15 is 0.0037
# Best MSE of voxel x=2,y=16 is 0.0038
# Best MSE of voxel x=2,y=17 is 0.0044
# Best MSE of voxel x=2,y=18 is 0.0028
# Best MSE of voxel x=2,y=19 is 0.0007
# Best MSE of voxel x=3,y=0 is 0.0081
# Best MSE of voxel x=3,y=1 is 0.0146
# Best MSE of voxel x=3,y=2 is 0.0105
# Best MSE of voxel x=3,y=3 is 0.0274
# Best MSE of voxel x=3,y=4 is 0.01
# Best MSE of voxel x=3,y=5 is 0.0035
# Best MSE of voxel x=3,y=6 is 0.0041
# Best MSE of voxel x=3,y=7 is 0.0059
# Best MSE of voxel x=3,y=8 is 0.0032
# Best MSE of voxel x=3,y=9 is 0.0032
# Best MSE of voxel x=3,y=10 is 0.0051
# Best MSE of voxel x=3,y=11 is 0.004
# Best MSE of voxel x=3,y=12 is 0.0069
# Best MSE of voxel x=3,y=13 is 0.0069
# Best MSE of voxel x=3,y=14 is 0.0039
# Best MSE of voxel x=3,y=15 is 0.0038
# Best MSE of voxel x=3,y=16 is 0.0072
# Best MSE of voxel x=3,y=17 is 0.0042
# Best MSE of voxel x=3,y=18 is 0.0036
# Best MSE of voxel x=3,y=19 is 0.0029
# Best MSE of voxel x=4,y=0 is 0.0025
# Best MSE of voxel x=4,y=1 is 0.0059
# Best MSE of voxel x=4,y=2 is 0.0193
# Best MSE of voxel x=4,y=3 is 0.0158
# Best MSE of voxel x=4,y=4 is 0.0203
# Best MSE of voxel x=4,y=5 is 0.0043
# Best MSE of voxel x=4,y=6 is 0.0071
# Best MSE of voxel x=4,y=7 is 0.0054
# Best MSE of voxel x=4,y=8 is 0.0047
# Best MSE of voxel x=4,y=9 is 0.0038
# Best MSE of voxel x=4,y=10 is 0.0028
# Best MSE of voxel x=4,y=11 is 0.0036
# Best MSE of voxel x=4,y=12 is 0.0058
# Best MSE of voxel x=4,y=13 is 0.0052
# Best MSE of voxel x=4,y=14 is 0.0045
# Best MSE of voxel x=4,y=15 is 0.0053
# Best MSE of voxel x=4,y=16 is 0.0058
# Best MSE of voxel x=4,y=17 is 0.0036
# Best MSE of voxel x=4,y=18 is 0.004
# Best MSE of voxel x=4,y=19 is 0.0041
# Best MSE of voxel x=5,y=0 is 0.0064
# Best MSE of voxel x=5,y=1 is 0.0032
# Best MSE of voxel x=5,y=2 is 0.0169
# Best MSE of voxel x=5,y=3 is 0.0163
# Best MSE of voxel x=5,y=4 is 0.0241
# Best MSE of voxel x=5,y=5 is 0.0113
# Best MSE of voxel x=5,y=6 is 0.0051
# Best MSE of voxel x=5,y=7 is 0.0071
# Best MSE of voxel x=5,y=8 is 0.0092
# Best MSE of voxel x=5,y=9 is 0.0075
# Best MSE of voxel x=5,y=10 is 0.0042
# Best MSE of voxel x=5,y=11 is 0.0136
# Best MSE of voxel x=5,y=12 is 0.0107
# Best MSE of voxel x=5,y=13 is 0.0089
# Best MSE of voxel x=5,y=14 is 0.0055
# Best MSE of voxel x=5,y=15 is 0.004
# Best MSE of voxel x=5,y=16 is 0.0064
# Best MSE of voxel x=5,y=17 is 0.0025
# Best MSE of voxel x=5,y=18 is 0.0037
# Best MSE of voxel x=5,y=19 is 0.0083
# Best MSE of voxel x=6,y=0 is 0.0023
# Best MSE of voxel x=6,y=1 is 0.0021
# Best MSE of voxel x=6,y=2 is 0.0084
# Best MSE of voxel x=6,y=3 is 0.0469
# Best MSE of voxel x=6,y=4 is 0.033
# Best MSE of voxel x=6,y=5 is 0.0172
# Best MSE of voxel x=6,y=6 is 0.0048
# Best MSE of voxel x=6,y=7 is 0.0142
# Best MSE of voxel x=6,y=8 is 0.0218
# Best MSE of voxel x=6,y=9 is 0.0125
# Best MSE of voxel x=6,y=10 is 0.0063
# Best MSE of voxel x=6,y=11 is 0.0102
# Best MSE of voxel x=6,y=12 is 0.0114
# Best MSE of voxel x=6,y=13 is 0.0094
# Best MSE of voxel x=6,y=14 is 0.0041
# Best MSE of voxel x=6,y=15 is 0.004
# Best MSE of voxel x=6,y=16 is 0.0026
# Best MSE of voxel x=6,y=17 is 0.0038
# Best MSE of voxel x=6,y=18 is 0.0052
# Best MSE of voxel x=6,y=19 is 0.0073
# Best MSE of voxel x=7,y=0 is 0.0019
# Best MSE of voxel x=7,y=1 is 0.0013
# Best MSE of voxel x=7,y=2 is 0.0049
# Best MSE of voxel x=7,y=3 is 0.0216
# Best MSE of voxel x=7,y=4 is 0.039
# Best MSE of voxel x=7,y=5 is 0.0217
# Best MSE of voxel x=7,y=6 is 0.011
# Best MSE of voxel x=7,y=7 is 0.0196
# Best MSE of voxel x=7,y=8 is 0.0241
# Best MSE of voxel x=7,y=9 is 0.0138
# Best MSE of voxel x=7,y=10 is 0.0072
# Best MSE of voxel x=7,y=11 is 0.0248
# Best MSE of voxel x=7,y=12 is 0.0106
# Best MSE of voxel x=7,y=13 is 0.0035
# Best MSE of voxel x=7,y=14 is 0.0037
# Best MSE of voxel x=7,y=15 is 0.0029
# Best MSE of voxel x=7,y=16 is 0.002
# Best MSE of voxel x=7,y=17 is 0.0037
# Best MSE of voxel x=7,y=18 is 0.0043
# Best MSE of voxel x=7,y=19 is 0.0057
# Best MSE of voxel x=8,y=0 is 0.0041
# Best MSE of voxel x=8,y=1 is 0.003
# Best MSE of voxel x=8,y=2 is 0.0024
# Best MSE of voxel x=8,y=3 is 0.0083
# Best MSE of voxel x=8,y=4 is 0.0107
# Best MSE of voxel x=8,y=5 is 0.0146
# Best MSE of voxel x=8,y=6 is 0.021
# Best MSE of voxel x=8,y=7 is 0.0171
# Best MSE of voxel x=8,y=8 is 0.0191
# Best MSE of voxel x=8,y=9 is 0.0074
# Best MSE of voxel x=8,y=10 is 0.0136
# Best MSE of voxel x=8,y=11 is 0.0179
# Best MSE of voxel x=8,y=12 is 0.0047
# Best MSE of voxel x=8,y=13 is 0.0031
# Best MSE of voxel x=8,y=14 is 0.0019
# Best MSE of voxel x=8,y=15 is 0.0034
# Best MSE of voxel x=8,y=16 is 0.0045
# Best MSE of voxel x=8,y=17 is 0.0039
# Best MSE of voxel x=8,y=18 is 0.0042
# Best MSE of voxel x=8,y=19 is 0.005
# Best MSE of voxel x=9,y=0 is 0.0049
# Best MSE of voxel x=9,y=1 is 0.006
# Best MSE of voxel x=9,y=2 is 0.002
# Best MSE of voxel x=9,y=3 is 0.0027
# Best MSE of voxel x=9,y=4 is 0.0188
# Best MSE of voxel x=9,y=5 is 0.0248
# Best MSE of voxel x=9,y=6 is 0.0093
# Best MSE of voxel x=9,y=7 is 0.0128
# Best MSE of voxel x=9,y=8 is 0.0115
# Best MSE of voxel x=9,y=9 is 0.0156
# Best MSE of voxel x=9,y=10 is 0.0219
# Best MSE of voxel x=9,y=11 is 0.0168
# Best MSE of voxel x=9,y=12 is 0.0071
# Best MSE of voxel x=9,y=13 is 0.0027
# Best MSE of voxel x=9,y=14 is 0.0038
# Best MSE of voxel x=9,y=15 is 0.0112
# Best MSE of voxel x=9,y=16 is 0.005
# Best MSE of voxel x=9,y=17 is 0.0066
# Best MSE of voxel x=9,y=18 is 0.0042
# Best MSE of voxel x=9,y=19 is 0.005
# Best MSE of voxel x=10,y=0 is 0.0043
# Best MSE of voxel x=10,y=1 is 0.0021
# Best MSE of voxel x=10,y=2 is 0.0049
# Best MSE of voxel x=10,y=3 is 0.0014
# Best MSE of voxel x=10,y=4 is 0.0016
# Best MSE of voxel x=10,y=5 is 0.0135
# Best MSE of voxel x=10,y=6 is 0.0211
# Best MSE of voxel x=10,y=7 is 0.0145
# Best MSE of voxel x=10,y=8 is 0.0114
# Best MSE of voxel x=10,y=9 is 0.0197
# Best MSE of voxel x=10,y=10 is 0.0176
# Best MSE of voxel x=10,y=11 is 0.0078
# Best MSE of voxel x=10,y=12 is 0.0073
# Best MSE of voxel x=10,y=13 is 0.0051
# Best MSE of voxel x=10,y=14 is 0.0045
# Best MSE of voxel x=10,y=15 is 0.0077
# Best MSE of voxel x=10,y=16 is 0.0048
# Best MSE of voxel x=10,y=17 is 0.0049
# Best MSE of voxel x=10,y=18 is 0.0065
# Best MSE of voxel x=10,y=19 is 0.008
# Best MSE of voxel x=11,y=0 is 0.0109
# Best MSE of voxel x=11,y=1 is 0.0017
# Best MSE of voxel x=11,y=2 is 0.0028
# Best MSE of voxel x=11,y=3 is 0.0032
# Best MSE of voxel x=11,y=4 is 0.0011
# Best MSE of voxel x=11,y=5 is 0.0071
# Best MSE of voxel x=11,y=6 is 0.0183
# Best MSE of voxel x=11,y=7 is 0.018
# Best MSE of voxel x=11,y=8 is 0.0135
# Best MSE of voxel x=11,y=9 is 0.0101
# Best MSE of voxel x=11,y=10 is 0.0211
# Best MSE of voxel x=11,y=11 is 0.0077
# Best MSE of voxel x=11,y=12 is 0.0051
# Best MSE of voxel x=11,y=13 is 0.0068
# Best MSE of voxel x=11,y=14 is 0.0057
# Best MSE of voxel x=11,y=15 is 0.0049
# Best MSE of voxel x=11,y=16 is 0.0052
# Best MSE of voxel x=11,y=17 is 0.0096
# Best MSE of voxel x=11,y=18 is 0.0077
# Best MSE of voxel x=11,y=19 is 0.0115
# Best MSE of voxel x=12,y=0 is 0.0165
# Best MSE of voxel x=12,y=1 is 0.004
# Best MSE of voxel x=12,y=2 is 0.0014
# Best MSE of voxel x=12,y=3 is 0.0013
# Best MSE of voxel x=12,y=4 is 0.006
# Best MSE of voxel x=12,y=5 is 0.0036
# Best MSE of voxel x=12,y=6 is 0.0175
# Best MSE of voxel x=12,y=7 is 0.0132
# Best MSE of voxel x=12,y=8 is 0.0182
# Best MSE of voxel x=12,y=9 is 0.0136
# Best MSE of voxel x=12,y=10 is 0.0126
# Best MSE of voxel x=12,y=11 is 0.0098
# Best MSE of voxel x=12,y=12 is 0.0032
# Best MSE of voxel x=12,y=13 is 0.0046
# Best MSE of voxel x=12,y=14 is 0.0065
# Best MSE of voxel x=12,y=15 is 0.0065
# Best MSE of voxel x=12,y=16 is 0.0086
# Best MSE of voxel x=12,y=17 is 0.0092
# Best MSE of voxel x=12,y=18 is 0.0111
# Best MSE of voxel x=12,y=19 is 0.013
# Best MSE of voxel x=13,y=0 is 0.0183
# Best MSE of voxel x=13,y=1 is 0.0095
# Best MSE of voxel x=13,y=2 is 0.0031
# Best MSE of voxel x=13,y=3 is 0.0015
# Best MSE of voxel x=13,y=4 is 0.0051
# Best MSE of voxel x=13,y=5 is 0.0014
# Best MSE of voxel x=13,y=6 is 0.0101
# Best MSE of voxel x=13,y=7 is 0.0137
# Best MSE of voxel x=13,y=8 is 0.0087
# Best MSE of voxel x=13,y=9 is 0.0111
# Best MSE of voxel x=13,y=10 is 0.0102
# Best MSE of voxel x=13,y=11 is 0.0084
# Best MSE of voxel x=13,y=12 is 0.0102
# Best MSE of voxel x=13,y=13 is 0.0099
# Best MSE of voxel x=13,y=14 is 0.011
# Best MSE of voxel x=13,y=15 is 0.0087
# Best MSE of voxel x=13,y=16 is 0.0126
# Best MSE of voxel x=13,y=17 is 0.0086
# Best MSE of voxel x=13,y=18 is 0.017
# Best MSE of voxel x=13,y=19 is 0.0064
# Best MSE of voxel x=14,y=0 is 0.0126
# Best MSE of voxel x=14,y=1 is 0.0102
# Best MSE of voxel x=14,y=2 is 0.0045
# Best MSE of voxel x=14,y=3 is 0.0064
# Best MSE of voxel x=14,y=4 is 0.0024
# Best MSE of voxel x=14,y=5 is 0.0026
# Best MSE of voxel x=14,y=6 is 0.0046
# Best MSE of voxel x=14,y=7 is 0.0123
# Best MSE of voxel x=14,y=8 is 0.0108
# Best MSE of voxel x=14,y=9 is 0.0107
# Best MSE of voxel x=14,y=10 is 0.0122
# Best MSE of voxel x=14,y=11 is 0.0089
# Best MSE of voxel x=14,y=12 is 0.0104
# Best MSE of voxel x=14,y=13 is 0.009
# Best MSE of voxel x=14,y=14 is 0.0112
# Best MSE of voxel x=14,y=15 is 0.0133
# Best MSE of voxel x=14,y=16 is 0.0147
# Best MSE of voxel x=14,y=17 is 0.0131
# Best MSE of voxel x=14,y=18 is 0.0121
# Best MSE of voxel x=14,y=19 is 0.0138
# Best MSE of voxel x=15,y=0 is 0.0076
# Best MSE of voxel x=15,y=1 is 0.012
# Best MSE of voxel x=15,y=2 is 0.0092
# Best MSE of voxel x=15,y=3 is 0.0093
# Best MSE of voxel x=15,y=4 is 0.0064
# Best MSE of voxel x=15,y=5 is 0.0095
# Best MSE of voxel x=15,y=6 is 0.0059
# Best MSE of voxel x=15,y=7 is 0.0088
# Best MSE of voxel x=15,y=8 is 0.0103
# Best MSE of voxel x=15,y=9 is 0.0079
# Best MSE of voxel x=15,y=10 is 0.0082
# Best MSE of voxel x=15,y=11 is 0.0146
# Best MSE of voxel x=15,y=12 is 0.0087
# Best MSE of voxel x=15,y=13 is 0.0051
# Best MSE of voxel x=15,y=14 is 0.0144
# Best MSE of voxel x=15,y=15 is 0.0101
# Best MSE of voxel x=15,y=16 is 0.0083
# Best MSE of voxel x=15,y=17 is 0.0085
# Best MSE of voxel x=15,y=18 is 0.0082
# Best MSE of voxel x=15,y=19 is 0.0082
# Best MSE of voxel x=16,y=0 is 0.0125
# Best MSE of voxel x=16,y=1 is 0.0054
# Best MSE of voxel x=16,y=2 is 0.007
# Best MSE of voxel x=16,y=3 is 0.0073
# Best MSE of voxel x=16,y=4 is 0.0079
# Best MSE of voxel x=16,y=5 is 0.0081
# Best MSE of voxel x=16,y=6 is 0.0091
# Best MSE of voxel x=16,y=7 is 0.0097
# Best MSE of voxel x=16,y=8 is 0.0067
# Best MSE of voxel x=16,y=9 is 0.0102
# Best MSE of voxel x=16,y=10 is 0.0123
# Best MSE of voxel x=16,y=11 is 0.009
# Best MSE of voxel x=16,y=12 is 0.0087
# Best MSE of voxel x=16,y=13 is 0.0054
# Best MSE of voxel x=16,y=14 is 0.0085
# Best MSE of voxel x=16,y=15 is 0.0072
# Best MSE of voxel x=16,y=16 is 0.0093
# Best MSE of voxel x=16,y=17 is 0.0132
# Best MSE of voxel x=16,y=18 is 0.0053
# Best MSE of voxel x=16,y=19 is 0.0117
# Best MSE of voxel x=17,y=0 is 0.0097
# Best MSE of voxel x=17,y=1 is 0.0083
# Best MSE of voxel x=17,y=2 is 0.0135
# Best MSE of voxel x=17,y=3 is 0.0131
# Best MSE of voxel x=17,y=4 is 0.008
# Best MSE of voxel x=17,y=5 is 0.0135
# Best MSE of voxel x=17,y=6 is 0.0084
# Best MSE of voxel x=17,y=7 is 0.011
# Best MSE of voxel x=17,y=8 is 0.0078
# Best MSE of voxel x=17,y=9 is 0.012
# Best MSE of voxel x=17,y=10 is 0.0072
# Best MSE of voxel x=17,y=11 is 0.0093
# Best MSE of voxel x=17,y=12 is 0.0119
# Best MSE of voxel x=17,y=13 is 0.0098
# Best MSE of voxel x=17,y=14 is 0.0114
# Best MSE of voxel x=17,y=15 is 0.007
# Best MSE of voxel x=17,y=16 is 0.0075
# Best MSE of voxel x=17,y=17 is 0.0057
# Best MSE of voxel x=17,y=18 is 0.0103
# Best MSE of voxel x=17,y=19 is 0.0078
# Best MSE of voxel x=18,y=0 is 0.0112
# Best MSE of voxel x=18,y=1 is 0.0118
# Best MSE of voxel x=18,y=2 is 0.0071
# Best MSE of voxel x=18,y=3 is 0.0106
# Best MSE of voxel x=18,y=4 is 0.0142
# Best MSE of voxel x=18,y=5 is 0.0124
# Best MSE of voxel x=18,y=6 is 0.0116
# Best MSE of voxel x=18,y=7 is 0.0096
# Best MSE of voxel x=18,y=8 is 0.0075
# Best MSE of voxel x=18,y=9 is 0.0051
# Best MSE of voxel x=18,y=10 is 0.012
# Best MSE of voxel x=18,y=11 is 0.0087
# Best MSE of voxel x=18,y=12 is 0.0065
# Best MSE of voxel x=18,y=13 is 0.0065
# Best MSE of voxel x=18,y=14 is 0.0104
# Best MSE of voxel x=18,y=15 is 0.0049
# Best MSE of voxel x=18,y=16 is 0.008
# Best MSE of voxel x=18,y=17 is 0.0125
# Best MSE of voxel x=18,y=18 is 0.0073
# Best MSE of voxel x=18,y=19 is 0.0045
# Best MSE of voxel x=19,y=0 is 0.0139
# Best MSE of voxel x=19,y=1 is 0.0106
# Best MSE of voxel x=19,y=2 is 0.0154
# Best MSE of voxel x=19,y=3 is 0.0126
# Best MSE of voxel x=19,y=4 is 0.0077
# Best MSE of voxel x=19,y=5 is 0.0141
# Best MSE of voxel x=19,y=6 is 0.0066
# Best MSE of voxel x=19,y=7 is 0.0073
# Best MSE of voxel x=19,y=8 is 0.0069
# Best MSE of voxel x=19,y=9 is 0.0107
# Best MSE of voxel x=19,y=10 is 0.0098
# Best MSE of voxel x=19,y=11 is 0.006
# Best MSE of voxel x=19,y=12 is 0.0067
# Best MSE of voxel x=19,y=13 is 0.009
# Best MSE of voxel x=19,y=14 is 0.0084
# Best MSE of voxel x=19,y=15 is 0.0088
# Best MSE of voxel x=19,y=16 is 0.008
# Best MSE of voxel x=19,y=17 is 0.0102
# Best MSE of voxel x=19,y=18 is 0.0044
# Best MSE of voxel x=19,y=19 is 0.0069
#
# Final MSE: 0.008695353759287639 and STD: 0.005712294959486329

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 5.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
#         print(f'Best MSE of voxel x={x},y={y} is {np.round(best_value,4)}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:10<00:00,  6.51s/it]
# Final MSE: 0.005457409362199287 and STD: 0.003173078210050289
# Wall time: 2min 10s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 1.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
#         print(f'Best MSE of voxel x={x},y={y} is {np.round(best_value,4)}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:01<00:00,  6.06s/it]
# Final MSE: 0.005406610278128987 and STD: 0.0032249079936449735
# Wall time: 2min 1s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 1.0, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
#         print(f'Best MSE of voxel x={x},y={y} is {np.round(best_value,4)}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
visualize_result(our_bas_model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [02:01<00:00,  6.09s/it]
# Final MSE: 0.005313279074518767 and STD: 0.0030394718387764404
# Wall time: 2min 2s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 0.2, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))
#         print(f'Best MSE of voxel x={x},y={y} is {np.round(best_value,4)}')

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
visualize_result(our_bas_model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:57<00:00,  5.89s/it]
# Final MSE: 0.004739696889637226 and STD: 0.0019920936513591002
# Wall time: 1min 59s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 100
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 0.01, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
visualize_result(our_bas_model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [01:54<00:00,  5.74s/it]
# Final MSE: 0.005856162053215045 and STD: 0.002455357834323142
# Wall time: 1min 56s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 500
T = 10

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 0.1, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
visualize_result(our_bas_model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [09:35<00:00, 28.78s/it]
# Final MSE: 0.004313986666250766 and STD: 0.0017441471598043296
# Wall time: 9min 36s

# %%
# %%time
# MAIN EVOLUTION PROCESS
d = 6
N = 500
T = 5

ball = gaussian_models.G1Ball()
stick = cylinder_models.C1Stick()
bas_model = MultiCompartmentModel(models=[stick, ball])

# IMAGE SELECTION

our_bas_model = {}
voxel_mse = np.zeros([roi['width'], roi['height']])

for x in tqdm.tqdm(range(roi['width'])):
    our_bas_model[x] = {}
    for y in range(roi['height']):

        voxel_signal = data_hcp_roi[x, 0, y, :]
        best_value, best_chromosome, _, _ = es_for_single_voxel(lambda ch: single_voxel_function(ch, bas_model, scheme_hcp, voxel_signal),
                                                         d, N, T, 2*N, 2, 0.2, 1/np.sqrt(2*d), 1/np.sqrt(2*np.sqrt(d)),
                                                         -1, R=domain_dict_to_array(bas_model.parameter_ranges))

        our_bas_model[x][y] = set_params_from_chrom(best_chromosome, bas_model, scheme_hcp, voxel_signal)

        voxel_mse[x][y] = our_bas_model[x][y].mean_squared_error(voxel_signal)

print()
print(f'Final MSE: {np.mean(voxel_mse)} and STD: {np.std(voxel_mse)}')
visualize_result(our_bas_model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [05:22<00:00, 16.12s/it]
# Final MSE: 0.004668016191103811 and STD: 0.002051872936035473
# Wall time: 5min 24s
